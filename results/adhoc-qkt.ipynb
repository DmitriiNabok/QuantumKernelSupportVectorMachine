# %% [markdown]
# # Global imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Qiskit
from qiskit import BasicAer
from qiskit.providers.aer import AerSimulator
from qiskit.circuit.library import ZZFeatureMap, PauliFeatureMap
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit_machine_learning.kernels import QuantumKernel
from qiskit.circuit import QuantumCircuit, ParameterVector
from qiskit_machine_learning.datasets import ad_hoc_data

# Scikit
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, GridSearchCV, ParameterGrid, StratifiedKFold
from sklearn import metrics
from sklearn.svm import SVC
from collections import Counter

# Customized score functions
from qksvm.scores import get_scores, print_scores, print_cv_scores
# Custom visualization tools
from qksvm.visualization_tools import plot_dataset, plot_predictions, plot_decisions

from qksvm.QuantumFeatureMap import QuantumFeatureMap
from qksvm.QuantumKernelTraining import QuantumKernelTraining
from qksvm.QuantumEmbedding import entangle

seed = 12345

# %% [markdown]
# # Qiskit Ad Hoc dataset

# %%
np.random.seed(seed=77)
algorithm_globals.random_seed = seed

# generate the dataset
adhoc_dimension = 2
X, y, _, _, adhoc_total = ad_hoc_data(
    training_size=200,
    test_size=2,
    n=adhoc_dimension,
    gap=0.2,
    plot_data=False,
    one_hot=False,
    include_sample_total=True
)
y = 2*y-1

print(f"Dataset statistics: {Counter(y)}")
# Out:
# Dataset statistics: Counter({-1: 200, 1: 200})

# %%
train_size = 100
test_size = 50
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    train_size=train_size, test_size=test_size,
    stratify=y, random_state=42,
)

print(f"Training target statistics: {Counter(y_train)}")
print(f"Testing target statistics: {Counter(y_test)}")
# Out:
# Training target statistics: Counter({-1: 50, 1: 50})
# Testing target statistics: Counter({1: 25, -1: 25})

# %%
# Visualize the dataset
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# visualize the dataset
xmin = 0; xmax = 2*np.pi
axes = [xmin, xmax, xmin, xmax]

ax1.set_title("Total", fontsize=22)
ax1.imshow(
    np.asmatrix(adhoc_total).T,
    interpolation="nearest",
    origin="lower",
    cmap=plt.cm.RdBu_r,
    extent=axes,
)

ax2.set_title("Train", fontsize=22)
plot_dataset(X_train, y_train, ax2, axes, marker='o', size=50, stepsize=1.0)
ax2.grid(False)

ax3.set_title("Test", fontsize=22)
plot_dataset(X_test, y_test, ax3, axes, marker='s', size=50, stepsize=1.0)
ax3.grid(False)

plt.rcParams['font.size'] = 15
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize the classifier

# %%
def plot_results(clf, N=20):
    
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(
        np.asmatrix(adhoc_total).T,
        interpolation="nearest",
        origin="lower",
        cmap=plt.cm.RdBu_r,
        extent=axes,
    )
    plot_predictions(clf, axs[1], axes, N=N)
    plot_dataset(X_test, y_test, axs[1], axes, marker='s', size=50, stepsize=1.0)
    plot_decisions(clf, axs[2], axes, N=N)
    plot_dataset(X_test, y_test, axs[2], axes, marker='s', size=50, stepsize=1.0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # RBF kernel

# %%
np.random.seed(seed)

param_grid = {
    "gamma": [0.001, 0.01, 0.1, 1.0, 5.0, 10.0],
    "C": [1, 5, 10, 20, 50, 100, 1000],
}

clf = GridSearchCV(
    estimator=SVC(kernel='rbf'),
    param_grid=param_grid,
    scoring='balanced_accuracy',
    n_jobs=1,
    refit=True,
    cv=StratifiedKFold(n_splits=2, shuffle=True, random_state=42),
)
clf.fit(X_train, y_train)

print('Best grid search parameters:', clf.best_params_)
print('Best training score:', clf.best_score_)

scores_ = get_scores(clf.best_estimator_, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(clf.best_estimator_, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(clf.best_estimator_, N=40)
# Out:
# Best grid search parameters: {'C': 1, 'gamma': 10.0}
# Best training score: 0.73
#
# Train set:
#    Balanced accuracy:  0.99
#                   F1:  0.99
#              ROC_AUC:  0.99
#                  MCC:  0.98
#
# Test set:
#    Balanced accuracy:  0.78
#                   F1:  0.78
#              ROC_AUC:  0.78
#                  MCC:  0.56

# %%
np.random.seed(seed)

scoring = 0 # 0=acc, 1=f1, 2=roc
best_score = 0.0
scores_tr = []
scores_tt = []

param_grid = {
    "gamma": [0.001, 0.01, 0.1, 1.0, 5.0, 8.0, 9.0, 10.0, 11.0],
    "C": [1, 5, 10, 20, 50, 100, 1000],
}

_train_size = 200
_test_size = 50
n_splits = 5

for _seed in np.random.randint(2**16-1, size=5):
    # print('rnd seed', _seed)

    cv = StratifiedShuffleSplit(
        n_splits=n_splits, 
        train_size=_train_size, test_size=_test_size, 
        random_state=_seed
    )

    i = 0
    for train, test in cv.split(X, y):
        i += 1
        # print(f"Train/Test CV Subset {i}")

        clf = GridSearchCV(
            estimator=SVC(kernel='rbf'),
            param_grid=param_grid,
            scoring='balanced_accuracy',
            n_jobs=1,
            refit=True,
            cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=_seed),
        )

        clf.fit(X[train,:], y[train])

        train_scores = get_scores(clf.best_estimator_, X[train,:], y[train])
        test_scores = get_scores(clf.best_estimator_, X[test,:], y[test])
        scores_tr.append(train_scores)
        scores_tt.append(test_scores)
        if test_scores[scoring] > best_score:
            best_score = test_scores[scoring]
            best_clf = clf.best_estimator_

print('')
print('==== Cross-Validation Scores ====')
print("\nBest train score: ", best_score)
print_cv_scores(scores_tr, title='Train set:')
print_cv_scores(scores_tt, title='Test set:')
# Out:
# ==== Cross-Validation Scores ====
#
# Best train score:  0.96
#
# Train set:
#    Balanced accuracy:  1.00 +- 0.00
#                   F1:  1.00 +- 0.00
#              ROC_AUC:  1.00 +- 0.00
#                  MCC:  0.99 +- 0.01
#
# Test set:
#    Balanced accuracy:  0.87 +- 0.05
#                   F1:  0.87 +- 0.05
#              ROC_AUC:  0.87 +- 0.05
#                  MCC:  0.75 +- 0.11

# %% [raw]
# Train  acc_tr        mcc_tr        acc_te        mcc_te
# 50     0.93 +- 0.12  0.86 +- 0.24  0.68 +- 0.08  0.37 +- 0.17
# 100    0.99 +- 0.01  0.98 +- 0.03  0.76 +- 0.07  0.53 +- 0.14
# 150    0.99 +- 0.01  0.99 +- 0.02  0.82 +- 0.07  0.65 +- 0.13
# 200    1.00 +- 0.00  0.99 +- 0.01  0.87 +- 0.05  0.75 +- 0.11

# %% [markdown]
# # QKT SVM

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=4,
    gates=['RY', 'CZ', 'rz', 'rx'], entanglement='ring',
    repeat=True
)
# ending layer
for i in range(fm.num_qubits):
    fm.ry(fm.encod_params[i%fm.num_features], i)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌──────────────┐              ┌──────────┐ ┌──────────┐ ┌──────────────┐               ┌──────────┐ ┌───────────┐ »
# q_0: ┤ Ry(2.0*x[0]) ├──■────────■──┤ Rz(θ[0]) ├─┤ Rx(θ[4]) ├─┤ Ry(2.0*x[0]) ├──■────────■───┤ Rz(θ[8]) ├─┤ Rx(θ[12]) ├─»
#      ├──────────────┤  │        │  ├──────────┤ ├──────────┤ ├──────────────┤  │        │   ├──────────┤ ├───────────┤ »
# q_1: ┤ Ry(2.0*x[1]) ├──■──■─────┼──┤ Rz(θ[1]) ├─┤ Rx(θ[5]) ├─┤ Ry(2.0*x[1]) ├──■──■─────┼───┤ Rz(θ[9]) ├─┤ Rx(θ[13]) ├─»
#      ├──────────────┤     │     │  ├──────────┤ ├──────────┤ ├──────────────┤     │     │  ┌┴──────────┤ ├───────────┤ »
# q_2: ┤ Ry(2.0*x[0]) ├─────■──■──┼──┤ Rz(θ[2]) ├─┤ Rx(θ[6]) ├─┤ Ry(2.0*x[0]) ├─────■──■──┼──┤ Rz(θ[10]) ├─┤ Rx(θ[14]) ├─»
#      ├──────────────┤        │  │  ├──────────┤ ├──────────┤ ├──────────────┤        │  │  ├───────────┤ ├───────────┤ »
# q_3: ┤ Ry(2.0*x[1]) ├────────■──■──┤ Rz(θ[3]) ├─┤ Rx(θ[7]) ├─┤ Ry(2.0*x[1]) ├────────■──■──┤ Rz(θ[11]) ├─┤ Rx(θ[15]) ├─»
#      └──────────────┘              └──────────┘ └──────────┘ └──────────────┘              └───────────┘ └───────────┘ »
# «     ┌──────────────┐              ┌───────────┐ ┌───────────┐ ┌──────────────┐              ┌───────────┐ »
# «q_0: ┤ Ry(2.0*x[0]) ├──■────────■──┤ Rz(θ[16]) ├─┤ Rx(θ[20]) ├─┤ Ry(2.0*x[0]) ├──■────────■──┤ Rz(θ[24]) ├─»
# «     ├──────────────┤  │        │  ├───────────┤ ├───────────┤ ├──────────────┤  │        │  ├───────────┤ »
# «q_1: ┤ Ry(2.0*x[1]) ├──■──■─────┼──┤ Rz(θ[17]) ├─┤ Rx(θ[21]) ├─┤ Ry(2.0*x[1]) ├──■──■─────┼──┤ Rz(θ[25]) ├─»
# «     ├──────────────┤     │     │  ├───────────┤ ├───────────┤ ├──────────────┤     │     │  ├───────────┤ »
# «q_2: ┤ Ry(2.0*x[0]) ├─────■──■──┼──┤ Rz(θ[18]) ├─┤ Rx(θ[22]) ├─┤ Ry(2.0*x[0]) ├─────■──■──┼──┤ Rz(θ[26]) ├─»
# «     ├──────────────┤        │  │  ├───────────┤ ├───────────┤ ├──────────────┤        │  │  ├───────────┤ »
# «q_3: ┤ Ry(2.0*x[1]) ├────────■──■──┤ Rz(θ[19]) ├─┤ Rx(θ[23]) ├─┤ Ry(2.0*x[1]) ├────────■──■──┤ Rz(θ[27]) ├─»
# «     └──────────────┘              └───────────┘ └───────────┘ └──────────────┘              └───────────┘ »
# «     ┌───────────┐ ┌──────────────┐
# «q_0: ┤ Rx(θ[28]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_1: ┤ Rx(θ[29]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├──────────────┤
# «q_2: ┤ Rx(θ[30]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_3: ┤ Rx(θ[31]) ├─┤ Ry(2.0*x[1]) ├
# «     └───────────┘ └──────────────┘
# SVCLoss optimal value:  33.827379998089256
# Optimal parameters: [5.32894821 2.55061915 0.18696249 3.47031897 3.53049233 4.24658007
#  5.70438964 4.74083823 5.03046819 3.48524228 4.47517642 6.56484039
#  1.43286141 1.700416   1.68985095 3.60891545 5.1494025  6.246426
#  5.95019859 5.97545678 3.60077295 4.98424147 3.10885196 1.91779688
#  3.03969506 5.77104705 6.55661914 4.03119347 6.32585108 2.10140428
#  0.20985142 4.56111842]
# Train scores:
#    Balanced accuracy:  0.90
#                   F1:  0.90
#              ROC_AUC:  0.90
#                  MCC:  0.80
#
# Test scores:
#    Balanced accuracy:  0.84
#                   F1:  0.84
#              ROC_AUC:  0.84
#                  MCC:  0.68

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=3,
    num_layers=2,
    gates=['rx', 'rz', 'cz', 'RY'], entanglement='ring',
    repeat=True,
)
# ending layer
# for i in range(fm.num_qubits):
#     fm.ry(fm.encod_params[i%fm.num_features], i)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌──────────┐ ┌──────────┐           ┌──────────────┐ ┌──────────┐  ┌──────────┐           ┌──────────────┐
# q_0: ┤ Rx(θ[0]) ├─┤ Rz(θ[3]) ├──■─────■──┤ Ry(2.0*x[0]) ├─┤ Rx(θ[6]) ├──┤ Rz(θ[9]) ├──■─────■──┤ Ry(2.0*x[1]) ├─
#      ├──────────┤ ├──────────┤  │     │  ├──────────────┤ ├──────────┤ ┌┴──────────┤  │     │  ├──────────────┤
# q_1: ┤ Rx(θ[1]) ├─┤ Rz(θ[4]) ├──■──■──┼──┤ Ry(2.0*x[1]) ├─┤ Rx(θ[7]) ├─┤ Rz(θ[10]) ├──■──■──┼──┤ Ry(2.0*x[0]) ├─
#      ├──────────┤ ├──────────┤     │  │  ├──────────────┤ ├──────────┤ ├───────────┤     │  │  ├──────────────┤
# q_2: ┤ Rx(θ[2]) ├─┤ Rz(θ[5]) ├─────■──■──┤ Ry(2.0*x[0]) ├─┤ Rx(θ[8]) ├─┤ Rz(θ[11]) ├─────■──■──┤ Ry(2.0*x[1]) ├─
#      └──────────┘ └──────────┘           └──────────────┘ └──────────┘ └───────────┘           └──────────────┘
# SVCLoss optimal value:  44.1376612802389
# Optimal parameters: [ 3.9192478   3.65409712 -0.74862452  2.01230948  2.58354815  1.78781164
#   4.25778001  4.27782834  7.78559148  0.72740144  0.63936372  7.83174859]
# Train scores:
#    Balanced accuracy:  0.86
#                   F1:  0.86
#              ROC_AUC:  0.86
#                  MCC:  0.72
#
# Test scores:
#    Balanced accuracy:  0.78
#                   F1:  0.78
#              ROC_AUC:  0.78
#                  MCC:  0.56

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['RY', 'CRZ', 'rz', 'rx', ], entanglement='ring',
    repeat=True,
)
# ending layer
for i in range(fm.num_qubits):
    fm.ry(fm.encod_params[i%fm.num_features], i)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌──────────────┐                                                                                                 »
# q_0: ┤ Ry(2.0*x[0]) ├────────■────────────────────────────────────────────────────────────────────────────────────────»
#      ├──────────────┤ ┌──────┴───────┐                                                                                »
# q_1: ┤ Ry(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────────────────────»
#      ├──────────────┤ └──────────────┘┌──────┴───────┐                                                                »
# q_2: ┤ Ry(2.0*x[0]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────────────────────»
#      ├──────────────┤                 └──────────────┘┌──────┴───────┐                                                »
# q_3: ┤ Ry(2.0*x[1]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────»
#      ├──────────────┤                                 └──────────────┘┌──────┴───────┐                                »
# q_4: ┤ Ry(2.0*x[0]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────»
#      ├──────────────┤                                                 └──────────────┘┌──────┴───────┐                »
# q_5: ┤ Ry(2.0*x[1]) ├─────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────»
#      ├──────────────┤                                                                 └──────────────┘┌──────┴───────┐»
# q_6: ┤ Ry(2.0*x[0]) ├─────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├»
#      ├──────────────┤                                                                                 └──────────────┘»
# q_7: ┤ Ry(2.0*x[1]) ├─────────────────────────────────────────────────────────────────────────────────────────────────»
#      └──────────────┘                                                                                                 »
# «                     ┌──────────────┐ ┌──────────┐  ┌──────────┐ ┌──────────────┐                                 »
# «q_0: ────────────────┤ Rz(2.0*x[1]) ├─┤ Rz(θ[0]) ├──┤ Rx(θ[8]) ├─┤ Ry(2.0*x[0]) ├────────■────────────────────────»
# «                     └──────┬───────┘ ├──────────┤  ├──────────┤ ├──────────────┤ ┌──────┴───────┐                »
# «q_1: ───────────────────────┼─────────┤ Rz(θ[1]) ├──┤ Rx(θ[9]) ├─┤ Ry(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├───────■────────»
# «                            │         ├──────────┤ ┌┴──────────┤ ├──────────────┤ └──────────────┘┌──────┴───────┐»
# «q_2: ───────────────────────┼─────────┤ Rz(θ[2]) ├─┤ Rx(θ[10]) ├─┤ Ry(2.0*x[0]) ├─────────────────┤ Rz(2.0*x[1]) ├»
# «                            │         ├──────────┤ ├───────────┤ ├──────────────┤                 └──────────────┘»
# «q_3: ───────────────────────┼─────────┤ Rz(θ[3]) ├─┤ Rx(θ[11]) ├─┤ Ry(2.0*x[1]) ├─────────────────────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├──────────────┤                                 »
# «q_4: ───────────────────────┼─────────┤ Rz(θ[4]) ├─┤ Rx(θ[12]) ├─┤ Ry(2.0*x[0]) ├─────────────────────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├──────────────┤                                 »
# «q_5: ───────────────────────┼─────────┤ Rz(θ[5]) ├─┤ Rx(θ[13]) ├─┤ Ry(2.0*x[1]) ├─────────────────────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├──────────────┤                                 »
# «q_6: ───────■───────────────┼─────────┤ Rz(θ[6]) ├─┤ Rx(θ[14]) ├─┤ Ry(2.0*x[0]) ├─────────────────────────────────»
# «     ┌──────┴───────┐       │         ├──────────┤ ├───────────┤ ├──────────────┤                                 »
# «q_7: ┤ Rz(2.0*x[0]) ├───────■─────────┤ Rz(θ[7]) ├─┤ Rx(θ[15]) ├─┤ Ry(2.0*x[1]) ├─────────────────────────────────»
# «     └──────────────┘                 └──────────┘ └───────────┘ └──────────────┘                                 »
# «                                                                                     ┌──────────────┐ ┌───────────┐ »
# «q_0: ────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├─┤ Rz(θ[16]) ├─»
# «                                                                                     └──────┬───────┘ ├───────────┤ »
# «q_1: ───────────────────────────────────────────────────────────────────────────────────────┼─────────┤ Rz(θ[17]) ├─»
# «                                                                                            │         ├───────────┤ »
# «q_2: ───────■───────────────────────────────────────────────────────────────────────────────┼─────────┤ Rz(θ[18]) ├─»
# «     ┌──────┴───────┐                                                                       │         ├───────────┤ »
# «q_3: ┤ Rz(2.0*x[0]) ├───────■───────────────────────────────────────────────────────────────┼─────────┤ Rz(θ[19]) ├─»
# «     └──────────────┘┌──────┴───────┐                                                       │         ├───────────┤ »
# «q_4: ────────────────┤ Rz(2.0*x[1]) ├───────■───────────────────────────────────────────────┼─────────┤ Rz(θ[20]) ├─»
# «                     └──────────────┘┌──────┴───────┐                                       │         ├───────────┤ »
# «q_5: ────────────────────────────────┤ Rz(2.0*x[0]) ├───────■───────────────────────────────┼─────────┤ Rz(θ[21]) ├─»
# «                                     └──────────────┘┌──────┴───────┐                       │         ├───────────┤ »
# «q_6: ────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────┤ Rz(θ[22]) ├─»
# «                                                     └──────────────┘┌──────┴───────┐       │         ├───────────┤ »
# «q_7: ────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■─────────┤ Rz(θ[23]) ├─»
# «                                                                     └──────────────┘                 └───────────┘ »
# «     ┌───────────┐ ┌──────────────┐
# «q_0: ┤ Rx(θ[24]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_1: ┤ Rx(θ[25]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├──────────────┤
# «q_2: ┤ Rx(θ[26]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_3: ┤ Rx(θ[27]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├──────────────┤
# «q_4: ┤ Rx(θ[28]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_5: ┤ Rx(θ[29]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├──────────────┤
# «q_6: ┤ Rx(θ[30]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├──────────────┤
# «q_7: ┤ Rx(θ[31]) ├─┤ Ry(2.0*x[1]) ├
# «     └───────────┘ └──────────────┘
# SVCLoss optimal value:  33.27094368972399
# Optimal parameters: [ 5.49929802  3.26989857 -1.83506905  1.50588782  4.57387255  3.71582722
#   8.31473736  3.75357109  6.4857402   5.91940873  3.16788732  4.09498431
#   0.11960055 -2.24338028  0.24857327  3.56127473  6.27893869  3.35141368
#   6.06042404  4.03862179  4.24503164  2.67554963  3.17915245  2.75116352
#   3.83666408  5.81456457  5.30579505  3.26011369  2.4891175   3.01587158
#   0.09450122  3.56174732]
# Train scores:
#    Balanced accuracy:  0.99
#                   F1:  0.99
#              ROC_AUC:  0.99
#                  MCC:  0.98
#
# Test scores:
#    Balanced accuracy:  0.88
#                   F1:  0.88
#              ROC_AUC:  0.88
#                  MCC:  0.76

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['RY', 'CRZ', 'rz', 'ry', 'rz'], entanglement='ring',
    repeat=True,
)
# ending layer
for i in range(fm.num_qubits):
    fm.ry(fm.encod_params[i%fm.num_features], i)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌──────────────┐                                                                                                 »
# q_0: ┤ Ry(2.0*x[0]) ├────────■────────────────────────────────────────────────────────────────────────────────────────»
#      ├──────────────┤ ┌──────┴───────┐                                                                                »
# q_1: ┤ Ry(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────────────────────»
#      ├──────────────┤ └──────────────┘┌──────┴───────┐                                                                »
# q_2: ┤ Ry(2.0*x[0]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────────────────────»
#      ├──────────────┤                 └──────────────┘┌──────┴───────┐                                                »
# q_3: ┤ Ry(2.0*x[1]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────»
#      ├──────────────┤                                 └──────────────┘┌──────┴───────┐                                »
# q_4: ┤ Ry(2.0*x[0]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────»
#      ├──────────────┤                                                 └──────────────┘┌──────┴───────┐                »
# q_5: ┤ Ry(2.0*x[1]) ├─────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────»
#      ├──────────────┤                                                                 └──────────────┘┌──────┴───────┐»
# q_6: ┤ Ry(2.0*x[0]) ├─────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├»
#      ├──────────────┤                                                                                 └──────────────┘»
# q_7: ┤ Ry(2.0*x[1]) ├─────────────────────────────────────────────────────────────────────────────────────────────────»
#      └──────────────┘                                                                                                 »
# «                     ┌──────────────┐ ┌──────────┐  ┌──────────┐ ┌───────────┐ ┌──────────────┐                 »
# «q_0: ────────────────┤ Rz(2.0*x[1]) ├─┤ Rz(θ[0]) ├──┤ Ry(θ[8]) ├─┤ Rz(θ[16]) ├─┤ Ry(2.0*x[0]) ├────────■────────»
# «                     └──────┬───────┘ ├──────────┤  ├──────────┤ ├───────────┤ ├──────────────┤ ┌──────┴───────┐»
# «q_1: ───────────────────────┼─────────┤ Rz(θ[1]) ├──┤ Ry(θ[9]) ├─┤ Rz(θ[17]) ├─┤ Ry(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├»
# «                            │         ├──────────┤ ┌┴──────────┤ ├───────────┤ ├──────────────┤ └──────────────┘»
# «q_2: ───────────────────────┼─────────┤ Rz(θ[2]) ├─┤ Ry(θ[10]) ├─┤ Rz(θ[18]) ├─┤ Ry(2.0*x[0]) ├─────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├───────────┤ ├──────────────┤                 »
# «q_3: ───────────────────────┼─────────┤ Rz(θ[3]) ├─┤ Ry(θ[11]) ├─┤ Rz(θ[19]) ├─┤ Ry(2.0*x[1]) ├─────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├───────────┤ ├──────────────┤                 »
# «q_4: ───────────────────────┼─────────┤ Rz(θ[4]) ├─┤ Ry(θ[12]) ├─┤ Rz(θ[20]) ├─┤ Ry(2.0*x[0]) ├─────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├───────────┤ ├──────────────┤                 »
# «q_5: ───────────────────────┼─────────┤ Rz(θ[5]) ├─┤ Ry(θ[13]) ├─┤ Rz(θ[21]) ├─┤ Ry(2.0*x[1]) ├─────────────────»
# «                            │         ├──────────┤ ├───────────┤ ├───────────┤ ├──────────────┤                 »
# «q_6: ───────■───────────────┼─────────┤ Rz(θ[6]) ├─┤ Ry(θ[14]) ├─┤ Rz(θ[22]) ├─┤ Ry(2.0*x[0]) ├─────────────────»
# «     ┌──────┴───────┐       │         ├──────────┤ ├───────────┤ ├───────────┤ ├──────────────┤                 »
# «q_7: ┤ Rz(2.0*x[0]) ├───────■─────────┤ Rz(θ[7]) ├─┤ Ry(θ[15]) ├─┤ Rz(θ[23]) ├─┤ Ry(2.0*x[1]) ├─────────────────»
# «     └──────────────┘                 └──────────┘ └───────────┘ └───────────┘ └──────────────┘                 »
# «                                                                                                     ┌──────────────┐ »
# «q_0: ────────────────────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├─»
# «                                                                                                     └──────┬───────┘ »
# «q_1: ───────■───────────────────────────────────────────────────────────────────────────────────────────────┼─────────»
# «     ┌──────┴───────┐                                                                                       │         »
# «q_2: ┤ Rz(2.0*x[1]) ├───────■───────────────────────────────────────────────────────────────────────────────┼─────────»
# «     └──────────────┘┌──────┴───────┐                                                                       │         »
# «q_3: ────────────────┤ Rz(2.0*x[0]) ├───────■───────────────────────────────────────────────────────────────┼─────────»
# «                     └──────────────┘┌──────┴───────┐                                                       │         »
# «q_4: ────────────────────────────────┤ Rz(2.0*x[1]) ├───────■───────────────────────────────────────────────┼─────────»
# «                                     └──────────────┘┌──────┴───────┐                                       │         »
# «q_5: ────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■───────────────────────────────┼─────────»
# «                                                     └──────────────┘┌──────┴───────┐                       │         »
# «q_6: ────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────»
# «                                                                     └──────────────┘┌──────┴───────┐       │         »
# «q_7: ────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■─────────»
# «                                                                                     └──────────────┘                 »
# «     ┌───────────┐ ┌───────────┐ ┌───────────┐ ┌──────────────┐
# «q_0: ┤ Rz(θ[24]) ├─┤ Ry(θ[32]) ├─┤ Rz(θ[40]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_1: ┤ Rz(θ[25]) ├─┤ Ry(θ[33]) ├─┤ Rz(θ[41]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_2: ┤ Rz(θ[26]) ├─┤ Ry(θ[34]) ├─┤ Rz(θ[42]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_3: ┤ Rz(θ[27]) ├─┤ Ry(θ[35]) ├─┤ Rz(θ[43]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_4: ┤ Rz(θ[28]) ├─┤ Ry(θ[36]) ├─┤ Rz(θ[44]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_5: ┤ Rz(θ[29]) ├─┤ Ry(θ[37]) ├─┤ Rz(θ[45]) ├─┤ Ry(2.0*x[1]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_6: ┤ Rz(θ[30]) ├─┤ Ry(θ[38]) ├─┤ Rz(θ[46]) ├─┤ Ry(2.0*x[0]) ├
# «     ├───────────┤ ├───────────┤ ├───────────┤ ├──────────────┤
# «q_7: ┤ Rz(θ[31]) ├─┤ Ry(θ[39]) ├─┤ Rz(θ[47]) ├─┤ Ry(2.0*x[1]) ├
# «     └───────────┘ └───────────┘ └───────────┘ └──────────────┘
# SVCLoss optimal value:  33.05304395434506
# Optimal parameters: [ 6.30065864  1.68418208 -1.76370488  1.44346388  4.05338992  1.91711163
#   7.22919096  2.50382793  5.81293479  2.45320195  3.13870916  3.11733438
#  -0.46947657 -1.04496451  0.5251883   5.17901913  7.3355031   6.13876435
#   6.72771222  4.52630085  5.03913325  2.76543606  1.84535008  2.78646165
#   4.03713143  6.85698129  5.00054156  2.70844732  8.09919429  1.41361496
#  -1.67908688  4.86878122  4.02290638  0.74829296  4.9459295   2.39057152
#   2.40983     0.93904341  6.4452761   3.51570671  4.61163162  0.32125969
#   2.81624076 -0.18501532  2.4182527   2.66261976  3.75250576  0.60912853]
# Train scores:
#    Balanced accuracy:  0.99
#                   F1:  0.99
#              ROC_AUC:  0.99
#                  MCC:  0.98
#
# Test scores:
#    Balanced accuracy:  0.82
#                   F1:  0.82
#              ROC_AUC:  0.82
#                  MCC:  0.64

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['H', 'RZ', 'ry', 'CRZ'], entanglement='ring',
    repeat=True,
)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐ ┌──────────────┐ ┌──────────┐                                                                 »
# q_0: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[0]) ├────────■────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ┌──────┴───────┐                                                »
# q_1: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[1]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ └──────────────┘┌──────┴───────┐                                »
# q_2: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[2]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤                 └──────────────┘┌──────┴───────┐                »
# q_3: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[3]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────»
#      ├───┤ ├──────────────┤ ├──────────┤                                 └──────────────┘┌──────┴───────┐»
# q_4: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[4]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├»
#      ├───┤ ├──────────────┤ ├──────────┤                                                 └──────────────┘»
# q_5: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[5]) ├─────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤                                                                 »
# q_6: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[6]) ├─────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤                                                                 »
# q_7: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[7]) ├─────────────────────────────────────────────────────────────────»
#      └───┘ └──────────────┘ └──────────┘                                                                 »
# «                                                     ┌──────────────┐ ┌───┐ ┌──────────────┐  ┌──────────┐ »
# «q_0: ────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├──┤ Ry(θ[8]) ├─»
# «                                                     └──────┬───────┘ ├───┤ ├──────────────┤  ├──────────┤ »
# «q_1: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├──┤ Ry(θ[9]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ┌┴──────────┤ »
# «q_2: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[10]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_3: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[11]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_4: ───────■───────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[12]) ├─»
# «     ┌──────┴───────┐                                       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_5: ┤ Rz(2.0*x[0]) ├───────■───────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[13]) ├─»
# «     └──────────────┘┌──────┴───────┐                       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_6: ────────────────┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[14]) ├─»
# «                     └──────────────┘┌──────┴───────┐       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_7: ────────────────────────────────┤ Rz(2.0*x[0]) ├───────■─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[15]) ├─»
# «                                     └──────────────┘                 └───┘ └──────────────┘ └───────────┘ »
# «                                                                                                                     »
# «q_0: ───────■────────────────────────────────────────────────────────────────────────────────────────────────────────»
# «     ┌──────┴───────┐                                                                                                »
# «q_1: ┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────────────────────────────────────»
# «     └──────────────┘┌──────┴───────┐                                                                                »
# «q_2: ────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────────────────────────────────────»
# «                     └──────────────┘┌──────┴───────┐                                                                »
# «q_3: ────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────»
# «                                     └──────────────┘┌──────┴───────┐                                                »
# «q_4: ────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────»
# «                                                     └──────────────┘┌──────┴───────┐                                »
# «q_5: ────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────»
# «                                                                     └──────────────┘┌──────┴───────┐                »
# «q_6: ────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────»
# «                                                                                     └──────────────┘┌──────┴───────┐»
# «q_7: ────────────────────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├»
# «                                                                                                     └──────────────┘»
# «     ┌──────────────┐
# «q_0: ┤ Rz(2.0*x[1]) ├─
# «     └──────┬───────┘
# «q_1: ───────┼─────────
# «            │
# «q_2: ───────┼─────────
# «            │
# «q_3: ───────┼─────────
# «            │
# «q_4: ───────┼─────────
# «            │
# «q_5: ───────┼─────────
# «            │
# «q_6: ───────┼─────────
# «            │
# «q_7: ───────■─────────
# «
# SVCLoss optimal value:  33.82535170758638
# Optimal parameters: [ 1.77468946 -1.20135025  1.7732523  -1.25945417 11.44247675  6.3868172
#   7.75450543  0.10819594  1.17653494  2.14103727  7.68224144  4.03345776
#   4.98517433 -1.85223487  5.40654001  1.92027188]
# Train scores:
#    Balanced accuracy:  0.99
#                   F1:  0.99
#              ROC_AUC:  0.99
#                  MCC:  0.98
#
# Test scores:
#    Balanced accuracy:  0.84
#                   F1:  0.84
#              ROC_AUC:  0.84
#                  MCC:  0.68

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['H', 'RZ', 'ry', 'rz', 'CRZ'], entanglement='ring',
    repeat=True,
)
fm.assign_parameters({fm.alpha: 2.0}, inplace=True)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐ ┌──────────────┐ ┌──────────┐  ┌──────────┐                                                                 »
# q_0: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[0]) ├──┤ Rz(θ[8]) ├────────■────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤  ├──────────┤ ┌──────┴───────┐                                                »
# q_1: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[1]) ├──┤ Rz(θ[9]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ┌┴──────────┤ └──────────────┘┌──────┴───────┐                                »
# q_2: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[2]) ├─┤ Rz(θ[10]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ├───────────┤                 └──────────────┘┌──────┴───────┐                »
# q_3: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[3]) ├─┤ Rz(θ[11]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ├───────────┤                                 └──────────────┘┌──────┴───────┐»
# q_4: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[4]) ├─┤ Rz(θ[12]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├»
#      ├───┤ ├──────────────┤ ├──────────┤ ├───────────┤                                                 └──────────────┘»
# q_5: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[5]) ├─┤ Rz(θ[13]) ├─────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ├───────────┤                                                                 »
# q_6: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[6]) ├─┤ Rz(θ[14]) ├─────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ├───────────┤                                                                 »
# q_7: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[7]) ├─┤ Rz(θ[15]) ├─────────────────────────────────────────────────────────────────»
#      └───┘ └──────────────┘ └──────────┘ └───────────┘                                                                 »
# «                                                     ┌──────────────┐ ┌───┐ ┌──────────────┐ ┌───────────┐ »
# «q_0: ────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[16]) ├─»
# «                                                     └──────┬───────┘ ├───┤ ├──────────────┤ ├───────────┤ »
# «q_1: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[17]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_2: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[18]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_3: ───────────────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[19]) ├─»
# «                                                            │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_4: ───────■───────────────────────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[20]) ├─»
# «     ┌──────┴───────┐                                       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_5: ┤ Rz(2.0*x[0]) ├───────■───────────────────────────────┼─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[21]) ├─»
# «     └──────────────┘┌──────┴───────┐                       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_6: ────────────────┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[22]) ├─»
# «                     └──────────────┘┌──────┴───────┐       │         ├───┤ ├──────────────┤ ├───────────┤ »
# «q_7: ────────────────────────────────┤ Rz(2.0*x[0]) ├───────■─────────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[23]) ├─»
# «                                     └──────────────┘                 └───┘ └──────────────┘ └───────────┘ »
# «     ┌───────────┐                                                                                                 »
# «q_0: ┤ Rz(θ[24]) ├────────■────────────────────────────────────────────────────────────────────────────────────────»
# «     ├───────────┤ ┌──────┴───────┐                                                                                »
# «q_1: ┤ Rz(θ[25]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────────────────────»
# «     ├───────────┤ └──────────────┘┌──────┴───────┐                                                                »
# «q_2: ┤ Rz(θ[26]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────────────────────»
# «     ├───────────┤                 └──────────────┘┌──────┴───────┐                                                »
# «q_3: ┤ Rz(θ[27]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────»
# «     ├───────────┤                                 └──────────────┘┌──────┴───────┐                                »
# «q_4: ┤ Rz(θ[28]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────»
# «     ├───────────┤                                                 └──────────────┘┌──────┴───────┐                »
# «q_5: ┤ Rz(θ[29]) ├─────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────»
# «     ├───────────┤                                                                 └──────────────┘┌──────┴───────┐»
# «q_6: ┤ Rz(θ[30]) ├─────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├»
# «     ├───────────┤                                                                                 └──────────────┘»
# «q_7: ┤ Rz(θ[31]) ├─────────────────────────────────────────────────────────────────────────────────────────────────»
# «     └───────────┘                                                                                                 »
# «                     ┌──────────────┐
# «q_0: ────────────────┤ Rz(2.0*x[1]) ├─
# «                     └──────┬───────┘
# «q_1: ───────────────────────┼─────────
# «                            │
# «q_2: ───────────────────────┼─────────
# «                            │
# «q_3: ───────────────────────┼─────────
# «                            │
# «q_4: ───────────────────────┼─────────
# «                            │
# «q_5: ───────────────────────┼─────────
# «                            │
# «q_6: ───────■───────────────┼─────────
# «     ┌──────┴───────┐       │
# «q_7: ┤ Rz(2.0*x[0]) ├───────■─────────
# «     └──────────────┘
# SVCLoss optimal value:  32.87702188009317
# Optimal parameters: [ 4.58566978  2.3081469   1.34383076  0.1730956   4.71633357  3.64631642
#   8.1565934   4.67059753  5.99065245  6.46266979  4.11239175  4.50479724
#  -1.43130599  0.38831335  0.43055685  3.02599604  8.12145715  6.44503964
#   7.3803946   4.61171493  4.77924001  4.80548644  1.16699113  3.74269043
#   2.46672744  6.13443311  4.42424658  3.28384941  7.45408881  1.17845998
#   1.55354806  3.5239107 ]
# Train scores:
#    Balanced accuracy:  0.98
#                   F1:  0.98
#              ROC_AUC:  0.98
#                  MCC:  0.96
#
# Test scores:
#    Balanced accuracy:  0.88
#                   F1:  0.88
#              ROC_AUC:  0.88
#                  MCC:  0.76

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=4,
    gates=['RY', 'cz', 'rz', 'rx', ], entanglement='ring',
    repeat=True, alpha=2.0,
)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌──────────────┐                          ┌──────────┐  ┌──────────┐ ┌──────────────┐                          »
# q_0: ┤ Ry(2.0*x[0]) ├──■────────────────────■──┤ Rz(θ[0]) ├──┤ Rx(θ[8]) ├─┤ Ry(2.0*x[0]) ├──■────────────────────■──»
#      ├──────────────┤  │                    │  ├──────────┤  ├──────────┤ ├──────────────┤  │                    │  »
# q_1: ┤ Ry(2.0*x[1]) ├──■──■─────────────────┼──┤ Rz(θ[1]) ├──┤ Rx(θ[9]) ├─┤ Ry(2.0*x[1]) ├──■──■─────────────────┼──»
#      ├──────────────┤     │                 │  ├──────────┤ ┌┴──────────┤ ├──────────────┤     │                 │  »
# q_2: ┤ Ry(2.0*x[0]) ├─────■──■──────────────┼──┤ Rz(θ[2]) ├─┤ Rx(θ[10]) ├─┤ Ry(2.0*x[0]) ├─────■──■──────────────┼──»
#      ├──────────────┤        │              │  ├──────────┤ ├───────────┤ ├──────────────┤        │              │  »
# q_3: ┤ Ry(2.0*x[1]) ├────────■──■───────────┼──┤ Rz(θ[3]) ├─┤ Rx(θ[11]) ├─┤ Ry(2.0*x[1]) ├────────■──■───────────┼──»
#      ├──────────────┤           │           │  ├──────────┤ ├───────────┤ ├──────────────┤           │           │  »
# q_4: ┤ Ry(2.0*x[0]) ├───────────■──■────────┼──┤ Rz(θ[4]) ├─┤ Rx(θ[12]) ├─┤ Ry(2.0*x[0]) ├───────────■──■────────┼──»
#      ├──────────────┤              │        │  ├──────────┤ ├───────────┤ ├──────────────┤              │        │  »
# q_5: ┤ Ry(2.0*x[1]) ├──────────────■──■─────┼──┤ Rz(θ[5]) ├─┤ Rx(θ[13]) ├─┤ Ry(2.0*x[1]) ├──────────────■──■─────┼──»
#      ├──────────────┤                 │     │  ├──────────┤ ├───────────┤ ├──────────────┤                 │     │  »
# q_6: ┤ Ry(2.0*x[0]) ├─────────────────■──■──┼──┤ Rz(θ[6]) ├─┤ Rx(θ[14]) ├─┤ Ry(2.0*x[0]) ├─────────────────■──■──┼──»
#      ├──────────────┤                    │  │  ├──────────┤ ├───────────┤ ├──────────────┤                    │  │  »
# q_7: ┤ Ry(2.0*x[1]) ├────────────────────■──■──┤ Rz(θ[7]) ├─┤ Rx(θ[15]) ├─┤ Ry(2.0*x[1]) ├────────────────────■──■──»
#      └──────────────┘                          └──────────┘ └───────────┘ └──────────────┘                          »
# «     ┌───────────┐ ┌───────────┐ ┌──────────────┐                          ┌───────────┐ ┌───────────┐ »
# «q_0: ┤ Rz(θ[16]) ├─┤ Rx(θ[24]) ├─┤ Ry(2.0*x[0]) ├──■────────────────────■──┤ Rz(θ[32]) ├─┤ Rx(θ[40]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤  │                    │  ├───────────┤ ├───────────┤ »
# «q_1: ┤ Rz(θ[17]) ├─┤ Rx(θ[25]) ├─┤ Ry(2.0*x[1]) ├──■──■─────────────────┼──┤ Rz(θ[33]) ├─┤ Rx(θ[41]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤     │                 │  ├───────────┤ ├───────────┤ »
# «q_2: ┤ Rz(θ[18]) ├─┤ Rx(θ[26]) ├─┤ Ry(2.0*x[0]) ├─────■──■──────────────┼──┤ Rz(θ[34]) ├─┤ Rx(θ[42]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤        │              │  ├───────────┤ ├───────────┤ »
# «q_3: ┤ Rz(θ[19]) ├─┤ Rx(θ[27]) ├─┤ Ry(2.0*x[1]) ├────────■──■───────────┼──┤ Rz(θ[35]) ├─┤ Rx(θ[43]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤           │           │  ├───────────┤ ├───────────┤ »
# «q_4: ┤ Rz(θ[20]) ├─┤ Rx(θ[28]) ├─┤ Ry(2.0*x[0]) ├───────────■──■────────┼──┤ Rz(θ[36]) ├─┤ Rx(θ[44]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤              │        │  ├───────────┤ ├───────────┤ »
# «q_5: ┤ Rz(θ[21]) ├─┤ Rx(θ[29]) ├─┤ Ry(2.0*x[1]) ├──────────────■──■─────┼──┤ Rz(θ[37]) ├─┤ Rx(θ[45]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤                 │     │  ├───────────┤ ├───────────┤ »
# «q_6: ┤ Rz(θ[22]) ├─┤ Rx(θ[30]) ├─┤ Ry(2.0*x[0]) ├─────────────────■──■──┼──┤ Rz(θ[38]) ├─┤ Rx(θ[46]) ├─»
# «     ├───────────┤ ├───────────┤ ├──────────────┤                    │  │  ├───────────┤ ├───────────┤ »
# «q_7: ┤ Rz(θ[23]) ├─┤ Rx(θ[31]) ├─┤ Ry(2.0*x[1]) ├────────────────────■──■──┤ Rz(θ[39]) ├─┤ Rx(θ[47]) ├─»
# «     └───────────┘ └───────────┘ └──────────────┘                          └───────────┘ └───────────┘ »
# «     ┌──────────────┐                          ┌───────────┐ ┌───────────┐
# «q_0: ┤ Ry(2.0*x[0]) ├──■────────────────────■──┤ Rz(θ[48]) ├─┤ Rx(θ[56]) ├─
# «     ├──────────────┤  │                    │  ├───────────┤ ├───────────┤
# «q_1: ┤ Ry(2.0*x[1]) ├──■──■─────────────────┼──┤ Rz(θ[49]) ├─┤ Rx(θ[57]) ├─
# «     ├──────────────┤     │                 │  ├───────────┤ ├───────────┤
# «q_2: ┤ Ry(2.0*x[0]) ├─────■──■──────────────┼──┤ Rz(θ[50]) ├─┤ Rx(θ[58]) ├─
# «     ├──────────────┤        │              │  ├───────────┤ ├───────────┤
# «q_3: ┤ Ry(2.0*x[1]) ├────────■──■───────────┼──┤ Rz(θ[51]) ├─┤ Rx(θ[59]) ├─
# «     ├──────────────┤           │           │  ├───────────┤ ├───────────┤
# «q_4: ┤ Ry(2.0*x[0]) ├───────────■──■────────┼──┤ Rz(θ[52]) ├─┤ Rx(θ[60]) ├─
# «     ├──────────────┤              │        │  ├───────────┤ ├───────────┤
# «q_5: ┤ Ry(2.0*x[1]) ├──────────────■──■─────┼──┤ Rz(θ[53]) ├─┤ Rx(θ[61]) ├─
# «     ├──────────────┤                 │     │  ├───────────┤ ├───────────┤
# «q_6: ┤ Ry(2.0*x[0]) ├─────────────────■──■──┼──┤ Rz(θ[54]) ├─┤ Rx(θ[62]) ├─
# «     ├──────────────┤                    │  │  ├───────────┤ ├───────────┤
# «q_7: ┤ Ry(2.0*x[1]) ├────────────────────■──■──┤ Rz(θ[55]) ├─┤ Rx(θ[63]) ├─
# «     └──────────────┘                          └───────────┘ └───────────┘
# SVCLoss optimal value:  37.70184542653186
# Optimal parameters: [ 5.64550052e+00  2.76032170e+00  2.99343358e+00  6.47962084e-03
#   2.47853655e+00  3.98422225e+00  5.80406994e+00  6.18513339e+00
#   5.32760810e+00  4.76750223e+00  3.55742414e+00  9.98797559e+00
#  -1.08790815e+00  1.28865053e+00  1.36231230e+00  5.50507293e+00
#   1.98385623e+00  7.82759437e+00  3.57211588e+00  4.72603914e+00
#   3.68192069e+00  7.11071721e+00  1.81647023e+00  3.66387872e+00
#   1.52811671e+00  1.36726350e+00  6.26742669e+00  3.72704463e+00
#   5.36157309e+00  1.89137652e+00 -1.07937942e+00  4.01076339e+00
#   4.92587823e+00 -1.96709915e-02  2.74937587e+00  6.36897109e+00
#   5.08576710e+00  1.50045841e-01  5.15625861e+00  2.84873844e+00
#   6.49832140e+00  3.04732267e+00  5.72120739e+00  1.32809886e-01
#   3.21703280e+00  2.90997889e+00  3.31827077e+00  2.98625515e+00
#   3.95790291e+00  3.02891692e+00  1.46196935e+00  1.99242701e+00
#   3.94196974e+00  5.49414016e+00  4.97311342e+00  1.40410142e+00
#   4.07532825e+00  3.29002174e+00  6.65530711e+00  6.29221464e+00
#   1.75829933e+00  3.54491551e+00  4.88294914e+00  3.60814164e+00]
# Train scores:
#    Balanced accuracy:  0.94
#                   F1:  0.94
#              ROC_AUC:  0.94
#                  MCC:  0.88
#
# Test scores:
#    Balanced accuracy:  0.76
#                   F1:  0.76
#              ROC_AUC:  0.76
#                  MCC:  0.52

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=4,
    gates=['H', 'RZ', 'ry', 'crx', ], entanglement='ring',
    repeat=True, scale=False, alpha=2.0,
)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐ ┌──────────────┐ ┌──────────┐                                                                             »
# q_0: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[0]) ├──────■──────────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ ┌────┴─────┐                                                                »
# q_1: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[1]) ├─┤ Rx(θ[8]) ├─────■──────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤ └──────────┘┌────┴─────┐                                                    »
# q_2: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[2]) ├─────────────┤ Rx(θ[9]) ├──────■─────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤             └──────────┘┌─────┴─────┐                                       »
# q_3: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[3]) ├─────────────────────────┤ Rx(θ[10]) ├──────■────────────────────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤                         └───────────┘┌─────┴─────┐                          »
# q_4: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[4]) ├──────────────────────────────────────┤ Rx(θ[11]) ├──────■───────────────────»
#      ├───┤ ├──────────────┤ ├──────────┤                                      └───────────┘┌─────┴─────┐             »
# q_5: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[5]) ├───────────────────────────────────────────────────┤ Rx(θ[12]) ├──────■──────»
#      ├───┤ ├──────────────┤ ├──────────┤                                                   └───────────┘┌─────┴─────┐»
# q_6: ┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[6]) ├────────────────────────────────────────────────────────────────┤ Rx(θ[13]) ├»
#      ├───┤ ├──────────────┤ ├──────────┤                                                                └───────────┘»
# q_7: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[7]) ├─────────────────────────────────────────────────────────────────────────────»
#      └───┘ └──────────────┘ └──────────┘                                                                             »
# «                  ┌───────────┐ ┌───┐ ┌──────────────┐ ┌───────────┐                                        »
# «q_0: ─────────────┤ Rx(θ[15]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[16]) ├───────■────────────────────────────────»
# «                  └─────┬─────┘ ├───┤ ├──────────────┤ ├───────────┤ ┌─────┴─────┐                          »
# «q_1: ───────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[17]) ├─┤ Rx(θ[24]) ├──────■───────────────────»
# «                        │       ├───┤ ├──────────────┤ ├───────────┤ └───────────┘┌─────┴─────┐             »
# «q_2: ───────────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[18]) ├──────────────┤ Rx(θ[25]) ├──────■──────»
# «                        │       ├───┤ ├──────────────┤ ├───────────┤              └───────────┘┌─────┴─────┐»
# «q_3: ───────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[19]) ├───────────────────────────┤ Rx(θ[26]) ├»
# «                        │       ├───┤ ├──────────────┤ ├───────────┤                           └───────────┘»
# «q_4: ───────────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[20]) ├────────────────────────────────────────»
# «                        │       ├───┤ ├──────────────┤ ├───────────┤                                        »
# «q_5: ───────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[21]) ├────────────────────────────────────────»
# «                        │       ├───┤ ├──────────────┤ ├───────────┤                                        »
# «q_6: ──────■────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[22]) ├────────────────────────────────────────»
# «     ┌─────┴─────┐      │       ├───┤ ├──────────────┤ ├───────────┤                                        »
# «q_7: ┤ Rx(θ[14]) ├──────■───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[23]) ├────────────────────────────────────────»
# «     └───────────┘              └───┘ └──────────────┘ └───────────┘                                        »
# «                                                         ┌───────────┐ ┌───┐ ┌──────────────┐ ┌───────────┐ »
# «q_0: ────────────────────────────────────────────────────┤ Rx(θ[31]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[32]) ├─»
# «                                                         └─────┬─────┘ ├───┤ ├──────────────┤ ├───────────┤ »
# «q_1: ──────────────────────────────────────────────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[33]) ├─»
# «                                                               │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_2: ──────────────────────────────────────────────────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[34]) ├─»
# «                                                               │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_3: ──────■───────────────────────────────────────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[35]) ├─»
# «     ┌─────┴─────┐                                             │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_4: ┤ Rx(θ[27]) ├──────■──────────────────────────────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[36]) ├─»
# «     └───────────┘┌─────┴─────┐                                │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_5: ─────────────┤ Rx(θ[28]) ├──────■─────────────────────────┼───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[37]) ├─»
# «                  └───────────┘┌─────┴─────┐                   │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_6: ──────────────────────────┤ Rx(θ[29]) ├──────■────────────┼───────┤ H ├─┤ Rz(2.0*x[0]) ├─┤ Ry(θ[38]) ├─»
# «                               └───────────┘┌─────┴─────┐      │       ├───┤ ├──────────────┤ ├───────────┤ »
# «q_7: ───────────────────────────────────────┤ Rx(θ[30]) ├──────■───────┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Ry(θ[39]) ├─»
# «                                            └───────────┘              └───┘ └──────────────┘ └───────────┘ »
# «                                                                                                ┌───────────┐ ┌───┐ »
# «q_0: ──────■────────────────────────────────────────────────────────────────────────────────────┤ Rx(θ[47]) ├─┤ H ├─»
# «     ┌─────┴─────┐                                                                              └─────┬─────┘ ├───┤ »
# «q_1: ┤ Rx(θ[40]) ├──────■─────────────────────────────────────────────────────────────────────────────┼───────┤ H ├─»
# «     └───────────┘┌─────┴─────┐                                                                       │       ├───┤ »
# «q_2: ─────────────┤ Rx(θ[41]) ├──────■────────────────────────────────────────────────────────────────┼───────┤ H ├─»
# «                  └───────────┘┌─────┴─────┐                                                          │       ├───┤ »
# «q_3: ──────────────────────────┤ Rx(θ[42]) ├──────■───────────────────────────────────────────────────┼───────┤ H ├─»
# «                               └───────────┘┌─────┴─────┐                                             │       ├───┤ »
# «q_4: ───────────────────────────────────────┤ Rx(θ[43]) ├──────■──────────────────────────────────────┼───────┤ H ├─»
# «                                            └───────────┘┌─────┴─────┐                                │       ├───┤ »
# «q_5: ────────────────────────────────────────────────────┤ Rx(θ[44]) ├──────■─────────────────────────┼───────┤ H ├─»
# «                                                         └───────────┘┌─────┴─────┐                   │       ├───┤ »
# «q_6: ─────────────────────────────────────────────────────────────────┤ Rx(θ[45]) ├──────■────────────┼───────┤ H ├─»
# «                                                                      └───────────┘┌─────┴─────┐      │       ├───┤ »
# «q_7: ──────────────────────────────────────────────────────────────────────────────┤ Rx(θ[46]) ├──────■───────┤ H ├─»
# «                                                                                   └───────────┘              └───┘ »
# «     ┌──────────────┐ ┌───────────┐                                                                               »
# «q_0: ┤ Rz(2.0*x[0]) ├─┤ Ry(θ[48]) ├───────■───────────────────────────────────────────────────────────────────────»
# «     ├──────────────┤ ├───────────┤ ┌─────┴─────┐                                                                 »
# «q_1: ┤ Rz(2.0*x[1]) ├─┤ Ry(θ[49]) ├─┤ Rx(θ[56]) ├──────■──────────────────────────────────────────────────────────»
# «     ├──────────────┤ ├───────────┤ └───────────┘┌─────┴─────┐                                                    »
# «q_2: ┤ Rz(2.0*x[0]) ├─┤ Ry(θ[50]) ├──────────────┤ Rx(θ[57]) ├──────■─────────────────────────────────────────────»
# «     ├──────────────┤ ├───────────┤              └───────────┘┌─────┴─────┐                                       »
# «q_3: ┤ Rz(2.0*x[1]) ├─┤ Ry(θ[51]) ├───────────────────────────┤ Rx(θ[58]) ├──────■────────────────────────────────»
# «     ├──────────────┤ ├───────────┤                           └───────────┘┌─────┴─────┐                          »
# «q_4: ┤ Rz(2.0*x[0]) ├─┤ Ry(θ[52]) ├────────────────────────────────────────┤ Rx(θ[59]) ├──────■───────────────────»
# «     ├──────────────┤ ├───────────┤                                        └───────────┘┌─────┴─────┐             »
# «q_5: ┤ Rz(2.0*x[1]) ├─┤ Ry(θ[53]) ├─────────────────────────────────────────────────────┤ Rx(θ[60]) ├──────■──────»
# «     ├──────────────┤ ├───────────┤                                                     └───────────┘┌─────┴─────┐»
# «q_6: ┤ Rz(2.0*x[0]) ├─┤ Ry(θ[54]) ├──────────────────────────────────────────────────────────────────┤ Rx(θ[61]) ├»
# «     ├──────────────┤ ├───────────┤                                                                  └───────────┘»
# «q_7: ┤ Rz(2.0*x[1]) ├─┤ Ry(θ[55]) ├───────────────────────────────────────────────────────────────────────────────»
# «     └──────────────┘ └───────────┘                                                                               »
# «                  ┌───────────┐
# «q_0: ─────────────┤ Rx(θ[63]) ├─
# «                  └─────┬─────┘
# «q_1: ───────────────────┼───────
# «                        │
# «q_2: ───────────────────┼───────
# «                        │
# «q_3: ───────────────────┼───────
# «                        │
# «q_4: ───────────────────┼───────
# «                        │
# «q_5: ───────────────────┼───────
# «                        │
# «q_6: ──────■────────────┼───────
# «     ┌─────┴─────┐      │
# «q_7: ┤ Rx(θ[62]) ├──────■───────
# «     └───────────┘
# SVCLoss optimal value:  38.19200894879248
# Optimal parameters: [ 4.61916038  1.81349575 -0.13768344  1.66186888  2.44221152  3.46223235
#   7.02021843  5.19105876  3.52977157  5.53577864  2.57149058  6.91437879
#  -1.75191619  1.25675503  1.46209443  6.99693922  2.81635395  6.03575471
#   5.26846693  4.23027662  5.30707364  5.59947982  2.5187474   2.48154538
#   2.68114912  3.00114321  5.23624213  3.49288671  5.01940977  0.4806958
#  -1.04940531  2.56977468  3.70425447  0.17294499  4.55416316  4.24341133
#   4.56602894 -0.85377178  5.63398905  5.54074597  6.26244345  1.04818046
#   4.28590006  1.51938987  2.47840452  3.80937567  2.68749986  0.70658415
#   4.07290754  1.63716851  1.51231438 -0.07881488  2.1374914   4.85302513
#   2.87178173  1.09726754  5.16665273  1.95278633  6.0523694   7.26365322
#   1.64270816  3.13853106  5.70524142  4.01913275]
# Train scores:
#    Balanced accuracy:  0.95
#                   F1:  0.95
#              ROC_AUC:  0.95
#                  MCC:  0.90
#
# Test scores:
#    Balanced accuracy:  0.76
#                   F1:  0.76
#              ROC_AUC:  0.76
#                  MCC:  0.52

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['H', 'RZ', 'CRZ', 'ry' ], entanglement='ring',
    repeat=True, scale=False, alpha=2.0,
)
print(fm.draw(plot_barriers=False, fold=120))

np.random.seed(seed)
init_params = np.random.uniform(0, 2*np.pi, len(fm.train_params))
qkt = QuantumKernelTraining(
    fm,
    X_train, y_train,
    init_params,
    seed=seed, plot=True,
)

# Model training
qsvc = SVC(kernel=qkt.quantum_kernel.evaluate, C=1, random_state=seed)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐ ┌──────────────┐                                                                                 »
# q_0: ┤ H ├─┤ Rz(2.0*x[0]) ├────────■────────────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ ┌──────┴───────┐                                                                »
# q_1: ┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├───────■────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤ └──────────────┘┌──────┴───────┐                                                »
# q_2: ┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────┤ Rz(2.0*x[1]) ├───────■────────────────────────────────────────»
#      ├───┤ ├──────────────┤                 └──────────────┘┌──────┴───────┐                                »
# q_3: ┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────────────────────┤ Rz(2.0*x[0]) ├───────■────────────────────────»
#      ├───┤ ├──────────────┤                                 └──────────────┘┌──────┴───────┐                »
# q_4: ┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■────────»
#      ├───┤ ├──────────────┤                                                 └──────────────┘┌──────┴───────┐»
# q_5: ┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├»
#      ├───┤ ├──────────────┤                                                                 └──────────────┘»
# q_6: ┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────────────────────────────────────────────────────────────────────»
#      ├───┤ ├──────────────┤                                                                                 »
# q_7: ┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────────────────────────────────────────────────────────────────────»
#      └───┘ └──────────────┘                                                                                 »
# «                                     ┌──────────────┐ ┌──────────┐ ┌───┐ ┌──────────────┐                 »
# «q_0: ────────────────────────────────┤ Rz(2.0*x[1]) ├─┤ Ry(θ[0]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├────────■────────»
# «                                     └──────┬───────┘ ├──────────┤ ├───┤ ├──────────────┤ ┌──────┴───────┐»
# «q_1: ───────────────────────────────────────┼─────────┤ Ry(θ[1]) ├─┤ H ├─┤ Rz(2.0*x[1]) ├─┤ Rz(2.0*x[0]) ├»
# «                                            │         ├──────────┤ ├───┤ ├──────────────┤ └──────────────┘»
# «q_2: ───────────────────────────────────────┼─────────┤ Ry(θ[2]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────»
# «                                            │         ├──────────┤ ├───┤ ├──────────────┤                 »
# «q_3: ───────────────────────────────────────┼─────────┤ Ry(θ[3]) ├─┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────»
# «                                            │         ├──────────┤ ├───┤ ├──────────────┤                 »
# «q_4: ───────────────────────────────────────┼─────────┤ Ry(θ[4]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────»
# «                                            │         ├──────────┤ ├───┤ ├──────────────┤                 »
# «q_5: ───────■───────────────────────────────┼─────────┤ Ry(θ[5]) ├─┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────»
# «     ┌──────┴───────┐                       │         ├──────────┤ ├───┤ ├──────────────┤                 »
# «q_6: ┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────┤ Ry(θ[6]) ├─┤ H ├─┤ Rz(2.0*x[0]) ├─────────────────»
# «     └──────────────┘┌──────┴───────┐       │         ├──────────┤ ├───┤ ├──────────────┤                 »
# «q_7: ────────────────┤ Rz(2.0*x[0]) ├───────■─────────┤ Ry(θ[7]) ├─┤ H ├─┤ Rz(2.0*x[1]) ├─────────────────»
# «                     └──────────────┘                 └──────────┘ └───┘ └──────────────┘                 »
# «                                                                                                     ┌──────────────┐ »
# «q_0: ────────────────────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├─»
# «                                                                                                     └──────┬───────┘ »
# «q_1: ───────■───────────────────────────────────────────────────────────────────────────────────────────────┼─────────»
# «     ┌──────┴───────┐                                                                                       │         »
# «q_2: ┤ Rz(2.0*x[1]) ├───────■───────────────────────────────────────────────────────────────────────────────┼─────────»
# «     └──────────────┘┌──────┴───────┐                                                                       │         »
# «q_3: ────────────────┤ Rz(2.0*x[0]) ├───────■───────────────────────────────────────────────────────────────┼─────────»
# «                     └──────────────┘┌──────┴───────┐                                                       │         »
# «q_4: ────────────────────────────────┤ Rz(2.0*x[1]) ├───────■───────────────────────────────────────────────┼─────────»
# «                                     └──────────────┘┌──────┴───────┐                                       │         »
# «q_5: ────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■───────────────────────────────┼─────────»
# «                                                     └──────────────┘┌──────┴───────┐                       │         »
# «q_6: ────────────────────────────────────────────────────────────────┤ Rz(2.0*x[1]) ├───────■───────────────┼─────────»
# «                                                                     └──────────────┘┌──────┴───────┐       │         »
# «q_7: ────────────────────────────────────────────────────────────────────────────────┤ Rz(2.0*x[0]) ├───────■─────────»
# «                                                                                     └──────────────┘                 »
# «      ┌──────────┐
# «q_0: ─┤ Ry(θ[8]) ├─
# «      ├──────────┤
# «q_1: ─┤ Ry(θ[9]) ├─
# «     ┌┴──────────┤
# «q_2: ┤ Ry(θ[10]) ├─
# «     ├───────────┤
# «q_3: ┤ Ry(θ[11]) ├─
# «     ├───────────┤
# «q_4: ┤ Ry(θ[12]) ├─
# «     ├───────────┤
# «q_5: ┤ Ry(θ[13]) ├─
# «     ├───────────┤
# «q_6: ┤ Ry(θ[14]) ├─
# «     ├───────────┤
# «q_7: ┤ Ry(θ[15]) ├─
# «     └───────────┘
# SVCLoss optimal value:  33.97292160101594
# Optimal parameters: [ 5.28108552  1.79437285  0.73678027 -1.18132353  7.16072462  5.58275805
#   7.619575    5.33758306  3.16550462  4.09326887  4.10811621  3.49918748
#   1.56233724 -2.06120088  1.46437914  1.41860154]
# Train scores:
#    Balanced accuracy:  1.00
#                   F1:  1.00
#              ROC_AUC:  1.00
#                  MCC:  1.00
#
# Test scores:
#    Balanced accuracy:  0.84
#                   F1:  0.84
#              ROC_AUC:  0.84
#                  MCC:  0.68
