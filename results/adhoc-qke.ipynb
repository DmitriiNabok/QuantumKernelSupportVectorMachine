# %% [markdown]
# # Global imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Qiskit
from qiskit import BasicAer
from qiskit.providers.aer import AerSimulator
from qiskit.circuit.library import ZZFeatureMap, PauliFeatureMap
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit_machine_learning.kernels import QuantumKernel
from qiskit.circuit import QuantumCircuit, ParameterVector, Parameter
from qiskit_machine_learning.datasets import ad_hoc_data

# Scikit
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, GridSearchCV, ParameterGrid, StratifiedKFold
from sklearn import metrics
from sklearn.svm import SVC
from collections import Counter

# Customized score functions
from qksvm.scores import get_scores, print_scores, print_cv_scores
# Custom visualization tools
from qksvm.visualization_tools import plot_dataset, plot_predictions, plot_decisions

from qksvm.QuantumFeatureMap import QuantumFeatureMap
from qksvm.QKSVC import QKSVC

seed = 12345

# %% [markdown]
# # Qiskit Ad Hoc dataset

# %%
np.random.seed(seed=77)
algorithm_globals.random_seed = seed

# generate the dataset
adhoc_dimension = 2
X, y, _, _, adhoc_total = ad_hoc_data(
    training_size=200,
    test_size=2,
    n=adhoc_dimension,
    gap=0.2,
    plot_data=False,
    one_hot=False,
    include_sample_total=True
)
y = 2*y-1

print(f"Dataset statistics: {Counter(y)}")
# Out:
# Dataset statistics: Counter({-1: 200, 1: 200})

# %%
train_size = 50
test_size = 50
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    train_size=train_size, test_size=test_size,
    stratify=y, random_state=42,
)

print(f"Training target statistics: {Counter(y_train)}")
print(f"Testing target statistics: {Counter(y_test)}")
# Out:
# Training target statistics: Counter({1: 25, -1: 25})
# Testing target statistics: Counter({-1: 25, 1: 25})

# %%
# Visualize the dataset
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# visualize the dataset
xmin = 0; xmax = 2*np.pi
axes = [xmin, xmax, xmin, xmax]

ax1.set_title("Total", fontsize=22)
ax1.imshow(
    np.asmatrix(adhoc_total).T,
    interpolation="nearest",
    origin="lower",
    cmap=plt.cm.RdBu_r,
    extent=axes,
)

ax2.set_title("Train", fontsize=22)
plot_dataset(X_train, y_train, ax2, axes, marker='o', size=50, stepsize=1.0)
ax2.grid(False)

ax3.set_title("Test", fontsize=22)
plot_dataset(X_test, y_test, ax3, axes, marker='s', size=50, stepsize=1.0)
ax3.grid(False)

plt.rcParams['font.size'] = 15
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize the classifier

# %%
def plot_results(clf, N=20):
    
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(
        np.asmatrix(adhoc_total).T,
        interpolation="nearest",
        origin="lower",
        cmap=plt.cm.RdBu_r,
        extent=axes,
    )
    plot_predictions(clf, axs[1], axes, N=N)
    plot_dataset(X_test, y_test, axs[1], axes, stepsize=1.0)
    plot_decisions(clf, axs[2], axes, N=N)
    plot_dataset(X_test, y_test, axs[2], axes, stepsize=1.0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # RBF kernel

# %%
np.random.seed(seed)

param_grid = {
    "gamma": [0.001, 0.01, 0.1, 1.0, 5.0, 10.0],
    "C": [1, 5, 10, 20, 50, 100, 1000],
}

clf = GridSearchCV(
    estimator=SVC(kernel='rbf'),
    param_grid=param_grid,
    scoring='balanced_accuracy',
    n_jobs=1,
    refit=True,
    cv=StratifiedKFold(n_splits=2, shuffle=True, random_state=42),
)
clf.fit(X_train, y_train)

print('Best grid search parameters:', clf.best_params_)
print('Best training score:', clf.best_score_)

scores_ = get_scores(clf.best_estimator_, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(clf.best_estimator_, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(clf.best_estimator_, N=40)
# Out:
# Best grid search parameters: {'C': 5, 'gamma': 1.0}
# Best training score: 0.6858974358974359
#
# Train set:
#    Balanced accuracy:  0.96
#                   F1:  0.96
#              ROC_AUC:  0.96
#                  MCC:  0.92
#
# Test set:
#    Balanced accuracy:  0.72
#                   F1:  0.72
#              ROC_AUC:  0.72
#                  MCC:  0.44

# %% [markdown]
# # QSVM
#
# ## Qiskit ZZFeatureMap

# %%
n_features = adhoc_dimension
n_qubits = 2
n_layers = 2

x = ParameterVector('x', length=n_qubits)
fm = QuantumCircuit(n_qubits)

for r in range(n_layers):
    for i in range(n_qubits):
        fm.h(i)
        fm.rz(2.0*x[i%n_features], i)
    if n_qubits > 1:
        for i in range(n_qubits-1):
            a = 2.0 * (np.pi-x[i]) * (np.pi-x[i+1])
            fm.rzz(a, i, i+1)
print(fm.draw(plot_barriers=False, fold=120))

# backend = QuantumInstance(
#     BasicAer.get_backend("qasm_simulator"), shots=1024, seed_simulator=seed, seed_transpiler=seed
# )
backend = QuantumInstance(
    AerSimulator(method="statevector"),
    seed_simulator=seed, seed_transpiler=seed,
    backend_options = {'method': 'automatic', 
                       'max_parallel_threads': 0,
                       'max_parallel_experiments': 0,
                       'max_parallel_shots': 0},
)

qkern = QuantumKernel(feature_map=fm, quantum_instance=backend)
qsvc = SVC(kernel=qkern.evaluate, C=1.0)
qsvc.fit(X_train, y_train)

scores_ = get_scores(qsvc, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(qsvc, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐┌──────────────┐                                ┌───┐┌──────────────┐
# q_0: ┤ H ├┤ Rz(2.0*x[0]) ├─■──────────────────────────────┤ H ├┤ Rz(2.0*x[0]) ├─■──────────────────────────────
#      ├───┤├──────────────┤ │ZZ(2.0*(π - x[0])*(π - x[1])) ├───┤├──────────────┤ │ZZ(2.0*(π - x[0])*(π - x[1]))
# q_1: ┤ H ├┤ Rz(2.0*x[1]) ├─■──────────────────────────────┤ H ├┤ Rz(2.0*x[1]) ├─■──────────────────────────────
#      └───┘└──────────────┘                                └───┘└──────────────┘
#
# Train set:
#    Balanced accuracy:  1.00
#                   F1:  1.00
#              ROC_AUC:  1.00
#                  MCC:  1.00
#
# Test set:
#    Balanced accuracy:  0.98
#                   F1:  0.98
#              ROC_AUC:  0.98
#                  MCC:  0.96

# %% [markdown]
# ## H-RZ-CX

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=2,
    num_layers=2,
    gates=['h', 'RZ', 'cx',], entanglement='linear',
)
print(fm.draw(plot_barriers=False, fold=120))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐       ┌───┐ ┌────────────┐
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───■───┤ H ├─┤ Rz(x[0]*α) ├───■───
#      ├───┤ ├────────────┤ ┌─┴─┐ ├───┤ ├────────────┤ ┌─┴─┐
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├─┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├─
#      └───┘ └────────────┘ └───┘ └───┘ └────────────┘ └───┘
#
# Train scores:
#    Balanced accuracy:  0.76
#                   F1:  0.76
#              ROC_AUC:  0.76
#                  MCC:  0.52
#
# Test scores:
#    Balanced accuracy:  0.76
#                   F1:  0.76
#              ROC_AUC:  0.76
#                  MCC:  0.54

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=2,
    gates=['h', 'RZ', 'cx',], entanglement='linear',
)
print(fm.draw(plot_barriers=False, fold=120))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐                 ┌───┐ ┌────────────┐
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───■─────────────┤ H ├─┤ Rz(x[0]*α) ├───■─────────────
#      ├───┤ ├────────────┤ ┌─┴─┐           ├───┤ ├────────────┤ ┌─┴─┐
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├──■────────┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├──■────────
#      ├───┤ ├────────────┤ └───┘┌─┴─┐      ├───┤ ├────────────┤ └───┘┌─┴─┐
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├──────┤ X ├──■───┤ H ├─┤ Rz(x[0]*α) ├──────┤ X ├──■───
#      ├───┤ ├────────────┤      └───┘┌─┴─┐ ├───┤ ├────────────┤      └───┘┌─┴─┐
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├───────────┤ X ├─┤ H ├─┤ Rz(x[1]*α) ├───────────┤ X ├─
#      └───┘ └────────────┘           └───┘ └───┘ └────────────┘           └───┘
#
# Train scores:
#    Balanced accuracy:  0.88
#                   F1:  0.88
#              ROC_AUC:  0.88
#                  MCC:  0.77
#
# Test scores:
#    Balanced accuracy:  0.76
#                   F1:  0.76
#              ROC_AUC:  0.76
#                  MCC:  0.54

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=2,
    gates=['h', 'RZ', 'CRX',], entanglement='ring',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=140))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐                                           ┌────────────┐ ┌───┐ ┌────────────┐                             »
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───────■───────────────────────────────────┤ Rx(x[1]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├───────■─────────────────────»
#      ├───┤ ├────────────┤ ┌─────┴──────┐                            └─────┬──────┘ ├───┤ ├────────────┤ ┌─────┴──────┐              »
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■───────────────────────────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■───────»
#      ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐                    │        ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐»
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■─────────────┼────────┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├»
#      ├───┤ ├────────────┤               └────────────┘┌─────┴──────┐      │        ├───┤ ├────────────┤               └────────────┘»
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├──────■────────┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────»
#      └───┘ └────────────┘                             └────────────┘               └───┘ └────────────┘                             »
# «                   ┌────────────┐
# «q_0: ──────────────┤ Rx(x[1]*α) ├─
# «                   └─────┬──────┘
# «q_1: ────────────────────┼────────
# «                         │
# «q_2: ──────■─────────────┼────────
# «     ┌─────┴──────┐      │
# «q_3: ┤ Rx(x[0]*α) ├──────■────────
# «     └────────────┘
#
# Train scores:
#    Balanced accuracy:  0.94
#                   F1:  0.94
#              ROC_AUC:  0.94
#                  MCC:  0.88
#
# Test scores:
#    Balanced accuracy:  0.70
#                   F1:  0.70
#              ROC_AUC:  0.70
#                  MCC:  0.40

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=4,
    gates=['h', 'RZ', 'CRX',], entanglement='ring',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=140))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐                                           ┌────────────┐ ┌───┐ ┌────────────┐                             »
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───────■───────────────────────────────────┤ Rx(x[1]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├───────■─────────────────────»
#      ├───┤ ├────────────┤ ┌─────┴──────┐                            └─────┬──────┘ ├───┤ ├────────────┤ ┌─────┴──────┐              »
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■───────────────────────────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■───────»
#      ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐                    │        ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐»
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■─────────────┼────────┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├»
#      ├───┤ ├────────────┤               └────────────┘┌─────┴──────┐      │        ├───┤ ├────────────┤               └────────────┘»
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├──────■────────┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────»
#      └───┘ └────────────┘                             └────────────┘               └───┘ └────────────┘                             »
# «                   ┌────────────┐ ┌───┐ ┌────────────┐                                           ┌────────────┐ ┌───┐ ┌────────────┐ »
# «q_0: ──────────────┤ Rx(x[1]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├───────■───────────────────────────────────┤ Rx(x[1]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├─»
# «                   └─────┬──────┘ ├───┤ ├────────────┤ ┌─────┴──────┐                            └─────┬──────┘ ├───┤ ├────────────┤ »
# «q_1: ────────────────────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■───────────────────────────┼────────┤ H ├─┤ Rz(x[1]*α) ├─»
# «                         │        ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐                    │        ├───┤ ├────────────┤ »
# «q_2: ──────■─────────────┼────────┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■─────────────┼────────┤ H ├─┤ Rz(x[0]*α) ├─»
# «     ┌─────┴──────┐      │        ├───┤ ├────────────┤               └────────────┘┌─────┴──────┐      │        ├───┤ ├────────────┤ »
# «q_3: ┤ Rx(x[0]*α) ├──────■────────┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├──────■────────┤ H ├─┤ Rz(x[1]*α) ├─»
# «     └────────────┘               └───┘ └────────────┘                             └────────────┘               └───┘ └────────────┘ »
# «                                               ┌────────────┐
# «q_0: ──────■───────────────────────────────────┤ Rx(x[1]*α) ├─
# «     ┌─────┴──────┐                            └─────┬──────┘
# «q_1: ┤ Rx(x[0]*α) ├──────■───────────────────────────┼────────
# «     └────────────┘┌─────┴──────┐                    │
# «q_2: ──────────────┤ Rx(x[1]*α) ├──────■─────────────┼────────
# «                   └────────────┘┌─────┴──────┐      │
# «q_3: ────────────────────────────┤ Rx(x[0]*α) ├──────■────────
# «                                 └────────────┘
#
# Train scores:
#    Balanced accuracy:  0.90
#                   F1:  0.90
#              ROC_AUC:  0.90
#                  MCC:  0.80
#
# Test scores:
#    Balanced accuracy:  0.70
#                   F1:  0.70
#              ROC_AUC:  0.70
#                  MCC:  0.41

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=8,
    num_layers=2,
    gates=['h', 'RZ', 'RY', 'CRX',], entanglement='ring',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=140))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐ ┌────────────┐                                                                                                   »
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────■───────────────────────────────────────────────────────────────────────────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤ ┌─────┴──────┐                                                                                    »
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■─────────────────────────────────────────────────────────────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤ └────────────┘┌─────┴──────┐                                                                      »
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■───────────────────────────────────────────────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤               └────────────┘┌─────┴──────┐                                                        »
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├──────■─────────────────────────────────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤                             └────────────┘┌─────┴──────┐                                          »
# q_4: ┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────────────────────────────────┤ Rx(x[1]*α) ├──────■───────────────────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤                                           └────────────┘┌─────┴──────┐                            »
# q_5: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─────────────────────────────────────────────────────────┤ Rx(x[0]*α) ├──────■─────────────────────»
#      ├───┤ ├────────────┤ ├────────────┤                                                         └────────────┘┌─────┴──────┐              »
# q_6: ┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────────────────────────────────────────────────────────────┤ Rx(x[1]*α) ├──────■───────»
#      ├───┤ ├────────────┤ ├────────────┤                                                                       └────────────┘┌─────┴──────┐»
# q_7: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─────────────────────────────────────────────────────────────────────────────────────┤ Rx(x[0]*α) ├»
#      └───┘ └────────────┘ └────────────┘                                                                                     └────────────┘»
# «     ┌────────────┐ ┌───┐ ┌────────────┐ ┌────────────┐                                                                       »
# «q_0: ┤ Rx(x[1]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────■───────────────────────────────────────────────────────────────»
# «     └─────┬──────┘ ├───┤ ├────────────┤ ├────────────┤ ┌─────┴──────┐                                                        »
# «q_1: ──────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■─────────────────────────────────────────────────»
# «           │        ├───┤ ├────────────┤ ├────────────┤ └────────────┘┌─────┴──────┐                                          »
# «q_2: ──────┼────────┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■───────────────────────────────────»
# «           │        ├───┤ ├────────────┤ ├────────────┤               └────────────┘┌─────┴──────┐                            »
# «q_3: ──────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├──────■─────────────────────»
# «           │        ├───┤ ├────────────┤ ├────────────┤                             └────────────┘┌─────┴──────┐              »
# «q_4: ──────┼────────┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────────────────────────────────┤ Rx(x[1]*α) ├──────■───────»
# «           │        ├───┤ ├────────────┤ ├────────────┤                                           └────────────┘┌─────┴──────┐»
# «q_5: ──────┼────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├─────────────────────────────────────────────────────────┤ Rx(x[0]*α) ├»
# «           │        ├───┤ ├────────────┤ ├────────────┤                                                         └────────────┘»
# «q_6: ──────┼────────┤ H ├─┤ Rz(x[0]*α) ├─┤ Ry(x[0]*α) ├───────────────────────────────────────────────────────────────────────»
# «           │        ├───┤ ├────────────┤ ├────────────┤                                                                       »
# «q_7: ──────■────────┤ H ├─┤ Rz(x[1]*α) ├─┤ Ry(x[1]*α) ├───────────────────────────────────────────────────────────────────────»
# «                    └───┘ └────────────┘ └────────────┘                                                                       »
# «                                 ┌────────────┐
# «q_0: ────────────────────────────┤ Rx(x[1]*α) ├─
# «                                 └─────┬──────┘
# «q_1: ──────────────────────────────────┼────────
# «                                       │
# «q_2: ──────────────────────────────────┼────────
# «                                       │
# «q_3: ──────────────────────────────────┼────────
# «                                       │
# «q_4: ──────────────────────────────────┼────────
# «                                       │
# «q_5: ──────■───────────────────────────┼────────
# «     ┌─────┴──────┐                    │
# «q_6: ┤ Rx(x[1]*α) ├──────■─────────────┼────────
# «     └────────────┘┌─────┴──────┐      │
# «q_7: ──────────────┤ Rx(x[0]*α) ├──────■────────
# «                   └────────────┘
#
# Train scores:
#    Balanced accuracy:  0.96
#                   F1:  0.96
#              ROC_AUC:  0.96
#                  MCC:  0.92
#
# Test scores:
#    Balanced accuracy:  0.64
#                   F1:  0.63
#              ROC_AUC:  0.64
#                  MCC:  0.30

# %%
fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=2,
    num_layers=2,
    gates=['h', 'RZ', 'RZZ', ], entanglement='full',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=120))

qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
qsvc.fit(X_train, y_train)

train_scores = get_scores(qsvc, X_train, y_train)
print_scores(train_scores, title='Train scores:')

test_scores  = get_scores(qsvc, X_test,  y_test)
print_scores(test_scores, title='Test scores:')

plot_results(qsvc, N=20)
# Out:
#      ┌───┐ ┌────────────┐                            ┌───┐ ┌────────────┐
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├──■────────────■────────────┤ H ├─┤ Rz(x[0]*α) ├──■────────────■────────────
#      ├───┤ ├────────────┤  │ZZ(x[0]*α)  │ZZ(x[1]*α)  ├───┤ ├────────────┤  │ZZ(x[0]*α)  │ZZ(x[1]*α)
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├──■────────────■────────────┤ H ├─┤ Rz(x[1]*α) ├──■────────────■────────────
#      └───┘ └────────────┘                            └───┘ └────────────┘
#
# Train scores:
#    Balanced accuracy:  0.80
#                   F1:  0.80
#              ROC_AUC:  0.80
#                  MCC:  0.60
#
# Test scores:
#    Balanced accuracy:  0.72
#                   F1:  0.72
#              ROC_AUC:  0.72
#                  MCC:  0.44

# %% [markdown]
# ## Model cross-validation

# %%
np.random.seed(seed)

fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=2,
    num_layers=2,
    gates=['h', 'RZ', 'cx',], entanglement='linear',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=120))

scoring = 0 # 0=acc, 1=f1, 2=roc
best_score = 0.0
scores_tr = []
scores_tt = []

# train_size = 10
# test_size = 10

n_splits = 5
# cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=100)
cv = StratifiedShuffleSplit(
    n_splits=n_splits, 
    train_size=train_size, test_size=test_size, 
    random_state=seed
)

i = 0
for train, test in cv.split(X, y):
    i += 1
    print(f"Train/Test CV Subset {i}")
    
    qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
    qsvc.fit(X[train,:], y[train])
   
    train_scores = get_scores(qsvc, X[train,:], y[train])
    test_scores = get_scores(qsvc, X[test,:], y[test])
    scores_tr.append(train_scores)
    scores_tt.append(test_scores)
    if test_scores[scoring] > best_score:
        best_score = test_scores[scoring]
        best_qsvc = qsvc

print('')
print('==== Cross-Validation Scores ====')
print("\nBest train score: ", best_score)
print_cv_scores(scores_tr, title='Train set:')
print_cv_scores(scores_tt, title='Test set:')
# Out:
#      ┌───┐ ┌────────────┐       ┌───┐ ┌────────────┐
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───■───┤ H ├─┤ Rz(x[0]*α) ├───■───
#      ├───┤ ├────────────┤ ┌─┴─┐ ├───┤ ├────────────┤ ┌─┴─┐
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├─┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├─
#      └───┘ └────────────┘ └───┘ └───┘ └────────────┘ └───┘
# Train/Test CV Subset 1
# Train/Test CV Subset 2
# Train/Test CV Subset 3
# Train/Test CV Subset 4
# Train/Test CV Subset 5
#
# ==== Cross-Validation Scores ====
#
# Best train score:  0.76
#
# Train set:
#    Balanced accuracy:  0.78 +- 0.06
#                   F1:  0.78 +- 0.07
#              ROC_AUC:  0.78 +- 0.06
#                  MCC:  0.57 +- 0.12
#
# Test set:
#    Balanced accuracy:  0.68 +- 0.06
#                   F1:  0.67 +- 0.06
#              ROC_AUC:  0.68 +- 0.06
#                  MCC:  0.37 +- 0.12

# %%
np.random.seed(seed)

fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=2,
    gates=['h', 'RZ', 'cx',], entanglement='linear',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=120))

scoring = 0 # 0=acc, 1=f1, 2=roc
best_score = 0.0
scores_tr = []
scores_tt = []

# train_size = 10
# test_size = 10

n_splits = 5
# cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=100)
cv = StratifiedShuffleSplit(
    n_splits=n_splits, 
    train_size=train_size, test_size=test_size, 
    random_state=seed
)

i = 0
for train, test in cv.split(X, y):
    i += 1
    print(f"Train/Test CV Subset {i}")
    
    qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
    qsvc.fit(X[train,:], y[train])
   
    train_scores = get_scores(qsvc, X[train,:], y[train])
    test_scores = get_scores(qsvc, X[test,:], y[test])
    scores_tr.append(train_scores)
    scores_tt.append(test_scores)
    if test_scores[scoring] > best_score:
        best_score = test_scores[scoring]
        best_qsvc = qsvc

print('')
print('==== Cross-Validation Scores ====')
print("\nBest train score: ", best_score)
print_cv_scores(scores_tr, title='Train set:')
print_cv_scores(scores_tt, title='Test set:')
# Out:
#      ┌───┐ ┌────────────┐                 ┌───┐ ┌────────────┐
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───■─────────────┤ H ├─┤ Rz(x[0]*α) ├───■─────────────
#      ├───┤ ├────────────┤ ┌─┴─┐           ├───┤ ├────────────┤ ┌─┴─┐
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├──■────────┤ H ├─┤ Rz(x[1]*α) ├─┤ X ├──■────────
#      ├───┤ ├────────────┤ └───┘┌─┴─┐      ├───┤ ├────────────┤ └───┘┌─┴─┐
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├──────┤ X ├──■───┤ H ├─┤ Rz(x[0]*α) ├──────┤ X ├──■───
#      ├───┤ ├────────────┤      └───┘┌─┴─┐ ├───┤ ├────────────┤      └───┘┌─┴─┐
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├───────────┤ X ├─┤ H ├─┤ Rz(x[1]*α) ├───────────┤ X ├─
#      └───┘ └────────────┘           └───┘ └───┘ └────────────┘           └───┘
# Train/Test CV Subset 1
# Train/Test CV Subset 2
# Train/Test CV Subset 3
# Train/Test CV Subset 4
# Train/Test CV Subset 5
#
# ==== Cross-Validation Scores ====
#
# Best train score:  0.76
#
# Train set:
#    Balanced accuracy:  0.85 +- 0.04
#                   F1:  0.85 +- 0.04
#              ROC_AUC:  0.85 +- 0.04
#                  MCC:  0.70 +- 0.07
#
# Test set:
#    Balanced accuracy:  0.70 +- 0.04
#                   F1:  0.70 +- 0.04
#              ROC_AUC:  0.70 +- 0.04
#                  MCC:  0.40 +- 0.09

# %%
np.random.seed(seed)

fm = QuantumFeatureMap(
    num_features=len(X[0]), 
    num_qubits=4,
    num_layers=2,
    gates=['h', 'RZ', 'CRX',], entanglement='linear',
    repeat=True,
)
print(fm.draw(plot_barriers=False, fold=120))

scoring = 0 # 0=acc, 1=f1, 2=roc
best_score = 0.0
scores_tr = []
scores_tt = []

# train_size = 10
# test_size = 10

n_splits = 5
cv = StratifiedShuffleSplit(
    n_splits=n_splits, 
    train_size=train_size, test_size=test_size, 
    random_state=seed
)

i = 0
for train, test in cv.split(X, y):
    i += 1
    print(f"Train/Test CV Subset {i}")
    
    qsvc = QKSVC(feature_map=fm, alpha=2.0, C=1, random_state=seed, backend=backend)
    qsvc.fit(X[train,:], y[train])
   
    train_scores = get_scores(qsvc, X[train,:], y[train])
    test_scores = get_scores(qsvc, X[test,:], y[test])
    scores_tr.append(train_scores)
    scores_tt.append(test_scores)
    if test_scores[scoring] > best_score:
        best_score = test_scores[scoring]
        best_qsvc = qsvc

print('')
print('==== Cross-Validation Scores ====')
print("\nBest train score: ", best_score)
print_cv_scores(scores_tr, title='Train set:')
print_cv_scores(scores_tt, title='Test set:')
# Out:
#      ┌───┐ ┌────────────┐                                            ┌───┐ ┌────────────┐                             »
# q_0: ┤ H ├─┤ Rz(x[0]*α) ├───────■────────────────────────────────────┤ H ├─┤ Rz(x[1]*α) ├───────■─────────────────────»
#      ├───┤ ├────────────┤ ┌─────┴──────┐                             ├───┤ ├────────────┤ ┌─────┴──────┐              »
# q_1: ┤ H ├─┤ Rz(x[1]*α) ├─┤ Rx(x[0]*α) ├──────■──────────────────────┤ H ├─┤ Rz(x[0]*α) ├─┤ Rx(x[1]*α) ├──────■───────»
#      ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐               ├───┤ ├────────────┤ └────────────┘┌─────┴──────┐»
# q_2: ┤ H ├─┤ Rz(x[0]*α) ├───────────────┤ Rx(x[1]*α) ├──────■────────┤ H ├─┤ Rz(x[1]*α) ├───────────────┤ Rx(x[0]*α) ├»
#      ├───┤ ├────────────┤               └────────────┘┌─────┴──────┐ ├───┤ ├────────────┤               └────────────┘»
# q_3: ┤ H ├─┤ Rz(x[1]*α) ├─────────────────────────────┤ Rx(x[0]*α) ├─┤ H ├─┤ Rz(x[0]*α) ├─────────────────────────────»
#      └───┘ └────────────┘                             └────────────┘ └───┘ └────────────┘                             »
# «
# «q_0: ───────────────
# «
# «q_1: ───────────────
# «
# «q_2: ──────■────────
# «     ┌─────┴──────┐
# «q_3: ┤ Rx(x[1]*α) ├─
# «     └────────────┘
# Train/Test CV Subset 1
# Train/Test CV Subset 2
# Train/Test CV Subset 3
# Train/Test CV Subset 4
# Train/Test CV Subset 5
#
# ==== Cross-Validation Scores ====
#
# Best train score:  0.86
#
# Train set:
#    Balanced accuracy:  0.94 +- 0.01
#                   F1:  0.94 +- 0.01
#              ROC_AUC:  0.94 +- 0.01
#                  MCC:  0.89 +- 0.03
#
# Test set:
#    Balanced accuracy:  0.69 +- 0.11
#                   F1:  0.69 +- 0.12
#              ROC_AUC:  0.69 +- 0.11
#                  MCC:  0.39 +- 0.22

# %% [markdown]
# # Test data non-linear transformation

# %%
def entangle(fm, gate, n, connectivity='linear'):
    gate = getattr(fm, gate)
    if connectivity=='full':
        for i in range(n):
            for ii in range(n):
                if i != ii:
                    gate(i, ii)
    else:
        if connectivity=='linear':
            m = n-1
        elif connectivity=='ring':
            m = n
        for i in range(0, m, 2):
            gate(i, (i+1)%n)
        for i in range(1, m, 2):
            gate(i, (i+1)%n)
    fm.barrier()

# %%
n_features = adhoc_dimension
n_qubits = 3
n_layers = 2

x = ParameterVector('x', length=n_qubits)
fm = QuantumCircuit(n_qubits)

alpha = 2.0
for r in range(n_layers):
    for i in range(n_features):
        fm.h(i)
        fm.rz(alpha*x[i%n_features], i)
    for i in range(n_features, n_qubits):
        fm.h(i)
        a = alpha * (np.pi-x[i%n_features]) * (np.pi-x[(i+1)%n_features])
        fm.rz(a, i)
    # entangle(fm, 'cx', n_qubits, connectivity='linear')
    for i in range(n_qubits):
        fm.cx(i, (i+1)%n_qubits)
    fm.barrier()
print(fm.draw(plot_barriers=False, fold=120))

algorithm_globals.random_seed = seed
backend = QuantumInstance(
    AerSimulator(method="statevector"),
    seed_simulator=seed, seed_transpiler=seed,
)

qkern = QuantumKernel(feature_map=fm, quantum_instance=backend)
qsvc = SVC(kernel=qkern.evaluate, C=1.0)
qsvc.fit(X_train, y_train)

scores_ = get_scores(qsvc, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(qsvc, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐         ┌──────────────┐                  ┌───┐ ┌───┐         ┌──────────────┐                  ┌───┐
# q_0: ┤ H ├─────────┤ Rz(2.0*x[0]) ├──────────■───────┤ X ├─┤ H ├─────────┤ Rz(2.0*x[0]) ├──────────■───────┤ X ├─
#      ├───┤         ├──────────────┤        ┌─┴─┐     └─┬─┘ ├───┤         ├──────────────┤        ┌─┴─┐     └─┬─┘
# q_1: ┤ H ├─────────┤ Rz(2.0*x[1]) ├────────┤ X ├──■────┼───┤ H ├─────────┤ Rz(2.0*x[1]) ├────────┤ X ├──■────┼───
#      ├───┤┌────────┴──────────────┴───────┐└───┘┌─┴─┐  │   ├───┤┌────────┴──────────────┴───────┐└───┘┌─┴─┐  │
# q_2: ┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─────┤ X ├──■───┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─────┤ X ├──■───
#      └───┘└───────────────────────────────┘     └───┘      └───┘└───────────────────────────────┘     └───┘
#
# Train set:
#    Balanced accuracy:  0.96
#                   F1:  0.96
#              ROC_AUC:  0.96
#                  MCC:  0.92
#
# Test set:
#    Balanced accuracy:  0.94
#                   F1:  0.94
#              ROC_AUC:  0.94
#                  MCC:  0.88

# %%
n_features = adhoc_dimension
n_qubits = 4
n_layers = 2

x = ParameterVector('x', length=n_qubits)
fm = QuantumCircuit(n_qubits)

alpha = 2.0
for r in range(n_layers):
    for i in range(n_features):
        fm.h(i)
        fm.rz(alpha*x[i%n_features], i)
    for i in range(n_features, n_qubits):
        fm.h(i)
        a = alpha * (np.pi-x[i%n_features]) * (np.pi-x[(i+1)%n_features])
        fm.rz(a, i)
    # entangle(fm, 'cx', n_qubits, connectivity='linear')
    for i in range(n_qubits):
        fm.cx(i, (i+1)%n_qubits)
    fm.barrier()
print(fm.draw(plot_barriers=False, fold=120))

algorithm_globals.random_seed = seed
backend = QuantumInstance(
    AerSimulator(method="statevector"),
    seed_simulator=seed, seed_transpiler=seed,
)

qkern = QuantumKernel(feature_map=fm, quantum_instance=backend)
qsvc = SVC(kernel=qkern.evaluate, C=1.0)
qsvc.fit(X_train, y_train)

scores_ = get_scores(qsvc, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(qsvc, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐         ┌──────────────┐                       ┌───┐ ┌───┐         ┌──────────────┐                       »
# q_0: ┤ H ├─────────┤ Rz(2.0*x[0]) ├──────────■────────────┤ X ├─┤ H ├─────────┤ Rz(2.0*x[0]) ├──────────■────────────»
#      ├───┤         ├──────────────┤        ┌─┴─┐          └─┬─┘ ├───┤         ├──────────────┤        ┌─┴─┐          »
# q_1: ┤ H ├─────────┤ Rz(2.0*x[1]) ├────────┤ X ├──■─────────┼───┤ H ├─────────┤ Rz(2.0*x[1]) ├────────┤ X ├──■───────»
#      ├───┤┌────────┴──────────────┴───────┐└───┘┌─┴─┐       │   ├───┤┌────────┴──────────────┴───────┐└───┘┌─┴─┐     »
# q_2: ┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─────┤ X ├──■────┼───┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─────┤ X ├──■──»
#      ├───┤├───────────────────────────────┤     └───┘┌─┴─┐  │   ├───┤├───────────────────────────────┤     └───┘┌─┴─┐»
# q_3: ┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├──────────┤ X ├──■───┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├──────────┤ X ├»
#      └───┘└───────────────────────────────┘          └───┘      └───┘└───────────────────────────────┘          └───┘»
# «     ┌───┐
# «q_0: ┤ X ├─
# «     └─┬─┘
# «q_1: ──┼───
# «       │
# «q_2: ──┼───
# «       │
# «q_3: ──■───
# «
#
# Train set:
#    Balanced accuracy:  1.00
#                   F1:  1.00
#              ROC_AUC:  1.00
#                  MCC:  1.00
#
# Test set:
#    Balanced accuracy:  0.96
#                   F1:  0.96
#              ROC_AUC:  0.96
#                  MCC:  0.92

# %%
n_features = adhoc_dimension
n_qubits = 4
n_layers = 2

x = ParameterVector('x', length=n_qubits)
fm = QuantumCircuit(n_qubits)

alpha = 2.0
for r in range(n_layers):
    for i in range(n_features):
        fm.h(i)
        fm.rz(alpha*x[i%n_features], i)
    for i in range(n_features, n_qubits):
        fm.h(i)
        a = alpha * (np.pi-x[i%n_features]) * (np.pi-x[(i+1)%n_features])
        fm.rz(a, i)
    # entangle(fm, 'cx', n_qubits, connectivity='linear')
    # for i in range(n_qubits):
    #     fm.cz(i, (i+1)%n_qubits)
    fm.barrier()
print(fm.draw(plot_barriers=False, fold=120))

algorithm_globals.random_seed = seed
backend = QuantumInstance(
    AerSimulator(method="statevector"),
    seed_simulator=seed, seed_transpiler=seed,
)

qkern = QuantumKernel(feature_map=fm, quantum_instance=backend)
qsvc = SVC(kernel=qkern.evaluate, C=1.0)
qsvc.fit(X_train, y_train)

scores_ = get_scores(qsvc, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(qsvc, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐         ┌──────────────┐         ┌───┐         ┌──────────────┐
# q_0: ┤ H ├─────────┤ Rz(2.0*x[0]) ├─────────┤ H ├─────────┤ Rz(2.0*x[0]) ├─────────
#      ├───┤         ├──────────────┤         ├───┤         ├──────────────┤
# q_1: ┤ H ├─────────┤ Rz(2.0*x[1]) ├─────────┤ H ├─────────┤ Rz(2.0*x[1]) ├─────────
#      ├───┤┌────────┴──────────────┴───────┐ ├───┤┌────────┴──────────────┴───────┐
# q_2: ┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─
#      ├───┤├───────────────────────────────┤ ├───┤├───────────────────────────────┤
# q_3: ┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─┤ H ├┤ Rz(2.0*(π - x[0])*(π - x[1])) ├─
#      └───┘└───────────────────────────────┘ └───┘└───────────────────────────────┘
#
# Train set:
#    Balanced accuracy:  0.92
#                   F1:  0.92
#              ROC_AUC:  0.92
#                  MCC:  0.85
#
# Test set:
#    Balanced accuracy:  0.94
#                   F1:  0.94
#              ROC_AUC:  0.94
#                  MCC:  0.89

# %%
n_features = adhoc_dimension
n_qubits = 3
n_layers = 1

x = ParameterVector('x', length=n_qubits)
fm = QuantumCircuit(n_qubits)

alpha = 2.0
for r in range(n_layers):
    fm.h(range(n_qubits))
    for i in range(n_features):
        fm.rz(alpha*x[i%n_features], i)
        
    # i=2; a = alpha * (np.pi-x[i%n_features]) * (np.pi-x[(i+1)%n_features]); fm.rz(a, i)
    # i=2; a = alpha * (x[i%n_features] + x[(i+1)%n_features]); fm.rz(a, i)
    # i=3; a = alpha * (x[i%n_features] - x[(i+1)%n_features]); fm.rz(a, i)
    i=2; a = alpha * np.cos(x[i%n_features]-x[(i+1)%n_features]); fm.rz(a, i)
        
    # entangle(fm, 'cx', n_qubits, connectivity='linear')
    # for i in range(n_qubits):
    #     fm.cz(i, (i+1)%n_qubits)
    fm.barrier()
print(fm.draw(plot_barriers=False, fold=120))

algorithm_globals.random_seed = seed
backend = QuantumInstance(
    AerSimulator(method="statevector"),
    seed_simulator=seed, seed_transpiler=seed,
)

qkern = QuantumKernel(feature_map=fm, quantum_instance=backend)
qsvc = SVC(kernel=qkern.evaluate, C=1.0)
qsvc.fit(X_train, y_train)

scores_ = get_scores(qsvc, X_train, y_train)
print_scores(scores_, title='Train set:')

scores_ = get_scores(qsvc, X_test, y_test)
print_scores(scores_, title='Test set:')

plot_results(qsvc, N=40)
# Out:
#      ┌───┐      ┌──────────────┐
# q_0: ┤ H ├──────┤ Rz(2.0*x[0]) ├───────
#      ├───┤      ├──────────────┤
# q_1: ┤ H ├──────┤ Rz(2.0*x[1]) ├───────
#      ├───┤┌─────┴──────────────┴─────┐
# q_2: ┤ H ├┤ Rz(2.0*cos(x[0] - x[1])) ├─
#      └───┘└──────────────────────────┘
#
# Train set:
#    Balanced accuracy:  0.80
#                   F1:  0.80
#              ROC_AUC:  0.80
#                  MCC:  0.60
#
# Test set:
#    Balanced accuracy:  0.68
#                   F1:  0.68
#              ROC_AUC:  0.68
#                  MCC:  0.36

# %% [raw]
# 3 1  0.84 0.68
# 3 2  0.92 0.84
# 3 3  0.74 0.49
# 3 4  0.84 0.69
#
# 4 1  0.86 0.73
# 4 2  0.96 0.92 <-- best
# 4 3  0.86 0.73
# 4 4  0.86 0.73
#
# Important observations:
# * Non-linear data transformation plays decisive role!
# * Gates with feature map transformation should be added as additional qubits
# * Order of entanglement gates plays a role (entanglement map), e.g., {[0, 1], [1, 2], [2, 3]} (stairs) <-> {[0,1]-[2,3], [1,2]} (compact)
#     * It seems that the entanglement topology is an additional hyperparameter!!!
